# %% [markdown]
# # Aula 11 - HTML e webscraping
#
# Na aula de hoje, vamos explorar os seguintes tópicos em Python:
#
# - 1) Web Front-end: HTML
# - 2) Webscraping
#
# _______

# %% [markdown]
# ____
# ____
# ____

# %% [markdown]
# ## 1) Web Front-end: HTML
#
# O desenvolvimento web é normalmente dividido em duas componentes: o **front-end** e o **back-end**.
#
# - front-end e refere à página que aparece no navegador do usuário. É a "fachada";
# - back-end é o que está por trás do site no servidor: comunicação, acesso a banco de dados etc.
#
# Enquanto no back-end qualquer linguagem pode ser usada, no front estamos limitados ao tripé **HTML, CSS e JavaScript**.
#
# - HTML é o "esqueleto" do site. É ele que irá posicionar diferentes elementos, como textos, figuras, vídeos entre outros na tela.
#
# - CSS serve para darmos estilo ao site. Podemos definir classes (e nelas definir comportamentos como cor, fonte e animações) para aplicar ao HTML.
#
# - JavaScript serve para aplicar lógica no próprio site, podendo rodar aplicações e deixar o site mais dinâmico.
#
# Para nossas aplicações de webscrapping, estaremos interessados apenas no HTML.

# %% [markdown]
# HTML é a sigla para **HyperText Markup Language**.
#
# Os "comandos" HTML são chamados de **tags**, e servem para marcar **pedaços do texto**, separando-os entre cabeçalho, corpo, tabelas, etc.
#
# As **tags HTML** são comandos iniciados em `<` e terminados em `>`.
#
# A maioria das tags vem em pares: utilizamos uma `<tag>`, colocamos algum conteúdo que desejamos que seja afetado por ela, e em seguida fechamos com  `</tag>`.
#
# Um documento HTML costuma abrir e fechar com as tags `<html>` e `</html>`.
#
# Em seguida, ele se subdivide em **head** e **body**.
#
# A tag `<head>` é o cabeçalho.
#
# > Nela colocamos informações úteis para o navegador interpretar o restante do documento, como padrões de estilo, links base, scripts etc.
#
# A tag `<body>` é aonde entra todo o conteúdo: textos, imagens, links...
#
# Um exemplo de código HTML para uma página bem simples (cole no bloco de notas):
#
# ```html
# <html>
#     <head>
#         <title>Meu primeiro site!</title>
#     </head>
#
#     <body>
#         <h1>Um site de exemplo</h1>
#         <h2>Site de exemplo pra entendermos HTML.</h2>
#         <p>Este é um site feio e bobo para vermos como HTML funciona.</p>
#         <p>Se você quer aprender HTML de verdade, clique <a href="https://letscode-academy.com/cursos/web-frontend-react">aqui</a>.</p>
#     </body>
# </html>
# ```

# %% [markdown]
# Podemos acessar o código-fonte HTML de qualquer site, de maneira bem simples!
#
# Podemos simplesmente clicar em algum lugar da página **com o botão direito**, e depois selecionar **exibir código-fonte**, ou algo do tipo (varia de navegador pra navegador).

# %% [markdown]
# Há também algumas ferramentas um pouco mais avançadas, que são de grande auxilio aos desenvolvedores, como o **inspecionador** ou **inspetor de elemento**
#
# Em navegadores como Chrome e Firefox atalhos como **ctrl+shift+i** ou **F12** funcionam.

# %% [markdown]
# Agora que conhecemos um pouco mais sobre HTML, vamos ao nosso objetivo principal: webscraping!

# %% [markdown]
# ___
# ___
# ___

# %% [markdown]
# ## 2) Webscraping
#
# O webscraping significa "raspagem de sites", e é exatamente esse o seu propósito: **extrair informações de um website**, para que estas possam ser utilizadas no Python.
#
# **Para que iríamos querer fazer isso?**
#
# Imagine que você queira coletar dados de um site que não disponibiliza uma API: usar webscraping é uma forma direta de fazer isso!
#
# Ou então, se vc precisa periodicamente tomar informações de um site, de forma automática.

# %% [markdown]
# A biblioteca padrão para webscraping do Python é o `beautiful soup`.
#
# Essa biblioteca é capaz de ler o HTML de um site, e criar um objeto a partir dele.
#
# Com isso, fica fácil acessar alguns elementos do site, como tabelas ou valores!
#
# Vamos aprender a usá-lo!

# %% [markdown]
# __IMPORTANTE: em webscraping, cada caso é um caso!!!!!!!!!!!!!!__
#
# Então, é importante aprender o princípio da técnica, e adapta-la para seu caso.
#
# Nesta aula, vamos extrair as informações resumidas sobre cada curso que a Let's Code oferece.
#
# Extrairemos: **título, pré-requisito e link para a página do curso.**
#
# O site é: https://letscode-academy.com/

# %%
import bs4

# %% [markdown]
# A primeira coisa é explorar o site, para descobrir como a informação que queremos extrair está codificada em HTML.
#
# Pelas ferramentas de inspeção de código e elementos em um navegador, observamos que todas elas estão contidas em tags `<a class='card__link'>`
#
# Vamos utilizar o bs4 para encontrar essa estrutura no HTML!
#
# O passo-a-passo é:
#
# - Use a requests para fazer uma requisição ao site, com o método `.get()`;
# - Capte o HTML do site com o atributo `.text`;
# - Instancie a classe `BeautifulSoup` da `bs4`para criar o objeto referente ao HTML;
#     - Os argumentos são o HTML captado do requests e o argumento "html.parser" para a construção do objeto
# - Com issso, o objeto está criado!
#
# ### OBSERVAÇÃO IMPORTANTE:
#
# Com o uso dos frameworks de frontend, há casos (como, por exemplo, do site da Let's Code até, pelo menos, Setembro de 2020) em que o HTML não está presente no código fonte da página, de modo a ser acessado imediatamente com a requests, pois o HTML é renderizado apenas no navegador. Nestes casos, é necessário usar o webdriver do selenium para que o HTML seja captado!
#
# Por esta ser uma abordagem mais geral, é ela que seguiremos aqui neste Notebook, e recomendamos ser seguida.
#
# No entanto, é importante frisar que **a única alteração** no procedimento é na forma como o HTML é capturado. Daí pra frente, o procedimento é **exatamente o mesmo** (do que seria se o HTML fosse capturado com o requests), com a utilização do bs4 para a criação do objeto sopa, e daí por diante.
#
# Assim, o passo-a-passo acima é alterado para:
#
# - Use o selenium e seu webdriver para fazer a requisição ao site, com o método `get()`;
# - Capte o HTML do site com os métodos `find_element_by_tag_name('body')` e `get_attribute('innerHTML')`;
# - Instancie a classe `BeautifulSoup` da `bs4`para criar o objeto referente ao HTML;
#     - Os argumentos são o HTML captado do requests e o argumento "html.parser" para a construção do objeto
# - Com isso, o objeto está criado!

# %%
# !pip install selenium

# %%
from selenium import webdriver

driver = webdriver.Chrome()
driver.get("http://letscode-academy.com/")
element = driver.find_element_by_tag_name(
    'body'
)
resposta = element.get_attribute(
    'innerHTML'
)

# %%
resposta
# Out:
# '<noscript>\n      <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-PQZB6GR&gtm_auth=&gtm_preview=&gtm_cookies_win=x"\n        height="0" width="0" style="display:none;visibility:hidden" id="tag-manager"></iframe></noscript><div id="__next"><div class="styles__Container-tke1hi-0 ilbCiQ"><div class="navbar is-fixed-top "><div><div class="navbar-brand"><a id="navbar-logo" class="navbar-item item-img" href="/"><img class="navbar-img  scrolled" src="/images/logoLcPng.png" alt="Home Let\'s Code" aria-label="Home Let\'s Code" height="120" width="120"></a></div></div><div class="navbar-menu  " hoverable="!false"><div class="navbar-end"><a class="navbar-item  active" href="/"><span class="nav-item-name">Home</span></a><a class="navbar-item  " href="/lets-code-zero"><span class="nav-item-name">Zero $</span></a><a class="navbar-item  " href="/nosso-time"><span class="nav-item-name">Nosso Time</span></a><div class="navbar-item  "><span class="nav-item-name">Cursos</span><span class="navbar-dropdown  "><div class="navbar-dropdown-container "><div class="multiple-dropdown-label1 "><svg stroke="currentColor" fill="none" stroke-width="2" viewBox="0 0 24 24" stroke-linecap="round" stroke-linejoin="round" height="1em" width="1em" xmlns="http://www.w3.org/2000/svg"><polyline points="18 15 12 9 6 15"></polyline></svg>Python &amp; Dados<div class="multiple-dropdown-options-container1"><div class="multiple-dropdown-options-container2"><div class="multiple-dropdown-options-container3 navbar-dropdown-container "><span class="multiple-dropdown-options-title">Quero me tornar um dev</span><a class="navbar-item  " href="/pi/ds">Data Science</a><span class="multiple-dropdown-options-title">Quero aprender a programar</span><a class="navbar-item  " href="/cursos/python_adulto">Python</a><a class="navbar-item  " href="/cursos/ds_ia">Data Science &amp; I.A</a><a class="navbar-item  " href="/cursos/python_finance">Python For Finance</a><a class="navbar-item  " href="/cursos/banco-de-dados">Banco De Dados</a><a class="navbar-item  " href="/curso-online/python-basics">Online Python Basics</a><a class="navbar-item  " href="/curso-online/python-teens">Python Teens</a></div></div></div></div></div><div class="navbar-dropdown-container "><div class="multiple-dropdown-label1 "><svg stroke="currentColor" fill="none" stroke-width="2" viewBox="0 0 24 24" stroke-linecap="round" stroke-linejoin="round" height="1em" width="1em" xmlns="http://www.w3.org/2000/svg"><polyline points="18 15 12 9 6 15"></polyline></svg>Web Full Stack<div class="multiple-dropdown-options-container1"><div class="multiple-dropdown-options-container2"><div class="multiple-dropdown-options-container3 navbar-dropdown-container "><span class="multiple-dropdown-options-title">Quero me tornar um dev</span><a class="navbar-item  " href="/pi/web">Web Full Stack</a><span class="multiple-dropdown-options-title">Quero aprender a programar</span><a class="navbar-item  " href="/cursos/web-frontend-react">Web Front-End &amp; React</a><a class="navbar-item  " href="/cursos/java">Java</a><a class="navbar-item  " href="/curso-online/web-and-react">Online Web &amp; React</a></div></div></div></div></div></span></div><a class="navbar-item  " href="/coding_challenge"><span class="nav-item-name">Eventos</span></a><a class="navbar-item  " href="/blog"><span class="nav-item-name">Blog</span></a><a class="navbar-item  " href="/certificado"><span class="nav-item-name">Certificados</span></a></div></div></div><div style="position:fixed;z-index:50;bottom:0;pointer-events:none;display:flex;width:100%;flex-direction:column"><div style="margin:10px;display:flex;pointer-events:none;flex-direction:row;justify-content:space-between"><a href="#header" class="scrollTop"><svg stroke="currentColor" fill="none" stroke-width="2" viewBox="0 0 24 24" stroke-linecap="round" stroke-linejoin="round" height="1em" width="1em" xmlns="http://www.w3.org/2000/svg"><polyline points="18 15 12 9 6 15"></polyline></svg></a><a target="_bla ...

# %%
# aqui, criamos um objeto da classe BeautifulSoup, passando como argumento
site = bs4.BeautifulSoup(resposta, 'html.parser')

# %%
print(site.prettify())
# Out:
# <noscript>
#  <iframe height="0" id="tag-manager" src="https://www.googletagmanager.com/ns.html?id=GTM-PQZB6GR&gt;m_auth=&gt;m_preview=&gt;m_cookies_win=x" style="display:none;visibility:hidden" width="0">
#  </iframe>
# </noscript>
# <div id="__next">
#  <div class="styles__Container-tke1hi-0 ilbCiQ">
#   <div class="navbar is-fixed-top">
#    <div>
#     <div class="navbar-brand">
#      <a class="navbar-item item-img" href="/" id="navbar-logo">
#       <img alt="Home Let's Code" aria-label="Home Let's Code" class="navbar-img scrolled" height="120" src="/images/logoLcPng.png" width="120"/>
#      </a>
#     </div>
#    </div>
#    <div class="navbar-menu" hoverable="!false">
#     <div class="navbar-end">
#      <a class="navbar-item active" href="/">
#       <span class="nav-item-name">
#        Home
#       </span>
#      </a>
#      <a class="navbar-item" href="/lets-code-zero">
#       <span class="nav-item-name">
#        Zero $
#       </span>
#      </a>
#      <a class="navbar-item" href="/nosso-time">
#       <span class="nav-item-name">
#        Nosso Time
#       </span>
#      </a>
#      <div class="navbar-item">
#       <span class="nav-item-name">
#        Cursos
#       </span>
#       <span class="navbar-dropdown">
#        <div class="navbar-dropdown-container">
#         <div class="multiple-dropdown-label1">
#          <svg fill="none" height="1em" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg">
#           <polyline points="18 15 12 9 6 15">
#           </polyline>
#          </svg>
#          Python &amp; Dados
#          <div class="multiple-dropdown-options-container1">
#           <div class="multiple-dropdown-options-container2">
#            <div class="multiple-dropdown-options-container3 navbar-dropdown-container">
#             <span class="multiple-dropdown-options-title">
#              Quero me tornar um dev
#             </span>
#             <a class="navbar-item" href="/pi/ds">
#              Data Science
#             </a>
#             <span class="multiple-dropdown-options-title">
#              Quero aprender a programar
#             </span>
#             <a class="navbar-item" href="/cursos/python_adulto">
#              Python
#             </a>
#             <a class="navbar-item" href="/cursos/ds_ia">
#              Data Science &amp; I.A
#             </a>
#             <a class="navbar-item" href="/cursos/python_finance">
#              Python For Finance
#             </a>
#             <a class="navbar-item" href="/cursos/banco-de-dados">
#              Banco De Dados
#             </a>
#             <a class="navbar-item" href="/curso-online/python-basics">
#              Online Python Basics
#             </a>
#             <a class="navbar-item" href="/curso-online/python-teens">
#              Python Teens
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="navbar-dropdown-container">
#         <div class="multiple-dropdown-label1">
#          <svg fill="none" height="1em" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg">
#           <polyline points="18 15 12 9 6 15">
#           </polyline>
#          </svg>
#          Web Full Stack
#          <div class="multiple-dropdown-options-container1">
#           <div class="multiple-dropdown-options-container2">
#            <div class="multiple-dropdown-options-container3 navbar-dropdown-container">
#             <span class="multiple-dropdown-options-title">
#              Quero me tornar um dev
#             </span>
#             <a class="navbar-item" href="/pi/web">
#              Web Full Stack
#             </a>
#             <span class="multiple-dropdown-options-title">
#              Quero aprender a programar
#             </span>
#             <a class="navbar-item" href="/cursos/web-frontend-react">
#              Web Front-End &amp; React
#             </a>
#             <a class="navbar-item" href="/cursos/java">
#              Java
#             </a>
#             <a class="navbar-item" href="/curso-online/web-and-react">
#              Online Web &amp; React
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </span>
#      </div>
#      <a class="navbar-item" href="/coding_challenge">
#       <span class="nav-item-name">
#        Eventos
#       </span>
#      </a>
#      <a class="navbar-item" href="/blog">
#       <span class="nav-item-name">
#        Blog
#       </span>
#      </a>
#      <a class="navbar-item" href="/certificado">
#       <span class="nav-item-name">
#        Certificados
#       </span>
#      </a>
#     </div>
#    </div>
#   </div>
#   <div style="position:fixed;z-index:50;bottom:0;pointer-events:none;display:flex;width:100%;flex-direction:column">
#    <div style="margin:10px;display:flex;pointer-events:none;flex-direction:row;justify-content:space-between">
#     <a class="scrollTop" href="#header">
#      <svg fill="none" height="1em" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg">
#       <polyline points="18 15 12 9 6 15">
#       </polyline>
#      </svg>
#     </a>
#     <a class="whatsLink" href="https://wa.me/5511933387373?text=Olá,%20gostaria%20de%20saber%20mais%20informações%20sobre%20os%20cursos%20da%20Let's%20Code." rel="noopener noreferrer" target="_blank">
#      <svg fill="currentColor" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 448 512" width="1em" xmlns="http://www.w3.org/2000/svg">
#       <path d="M380.9 97.1C339 55.1 283.2 32 223.9 32c-122.4 0-222 99.6-222 222 0 39.1 10.2 77.3 29.6 111L0 480l117.7-30.9c32.4 17.7 68.9 27 106.1 27h.1c122.3 0 224.1-99.6 224.1-222 0-59.3-25.2-115-67.1-157zm-157 341.6c-33.2 0-65.7-8.9-94-25.7l-6.7-4-69.8 18.3L72 359.2l-4.4-7c-18.5-29.4-28.2-63.3-28.2-98.2 0-101.7 82.8-184.5 184.6-184.5 49.3 0 95.6 19.2 130.4 54.1 34.8 34.9 56.2 81.2 56.1 130.5 0 101.8-84.9 184.6-186.6 184.6zm101.2-138.2c-5.5-2.8-32.8-16.2-37.9-18-5.1-1.9-8.8-2.8-12.5 2.8-3.7 5.6-14.3 18-17.6 21.8-3.2 3.7-6.5 4.2-12 1.4-32.6-16.3-54-29.1-75.5-66-5.7-9.8 5.7-9.1 16.3-30.3 1.8-3.7.9-6.9-.5-9.7-1.4-2.8-12.5-30.1-17.1-41.2-4.5-10.8-9.1-9.3-12.5-9.5-3.2-.2-6.9-.2-10.6-.2-3.7 0-9.7 1.4-14.8 6.9-5.1 5.6-19.4 19-19.4 46.3 0 27.3 19.9 53.7 22.6 57.4 2.8 3.7 39.1 59.7 94.8 83.8 35.2 15.2 49 16.5 66.6 13.9 10.7-1.6 32.8-13.4 37.4-26.4 4.6-13 4.6-24.1 3.2-26.4-1.3-2.5-5-3.9-10.5-6.6z">
#       </path>
#      </svg>
#     </a>
#    </div>
#    <div class="styles__Container-sc-1lny31g-0 ccWvLE">
#     <div class="cookie-accept">
#      <div class="container">
#       <div class="row">
#        <p class="cookie-text">
#         Ao navegar pelo nosso site, você concorda com a nossa
#         <br/>
#         <a href="/privacidade">
#          política de privacidade.
#         </a>
#        </p>
#        <button class="btn cookie-ok" type="button">
#         Ok, entendi.
#        </button>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div>
#  </div>
#  <div class="homeContainer__Container-cwo9us-0 dIRCRm">
#   <div class="headerContainer__Container-lvlhxg-0 iyFBhb">
#    <div class="courseContainer__Container-sc-38zdqz-0 fTiJWT">
#     <section class="homeHeader" id="header">
#      <svg class="headerCamada_1" enable-background="new 0 0 1905.5 620" version="1.1" viewbox="34 -247 1905.5 626" x="0px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#       <path class="st0" d="M1925.64,0v291.89H0v-13.21c0,0,280.36,18.03,650.83-84.44c370.47-102.47,407.23-103.27,552.25-76.32 c145.02,26.95,404.43,59.43,573.96-25.24C1845.52,58.49,1893.16,26.27,1925.64,0z">
#       </path>
#      </svg>
#      <svg class="headerCamada_1" enable-background="new 0 0 1905.5 612" version="1.1" viewbox="60 -240 1905.5 612" x="0px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#       <path class="st1" d="M24.49,282.91c0,0,280.36,18.03,650.83-84.44C1045.79,96,1082.55,95.21,1227.57,122.16 c145.02,26.95,404.43,59.43,573.96-25.24C1873.74,60.86,1922.77,27,1955.29,0h15.82v338.91H0">
#       </path>
#      </svg>
#      <div class="hero-container">
#       <div class="headerTextContainer">
#        <div class="lottieContainer">
#         <div aria-label="animation" role="button" style="width:500px;height:120px;overflow:hidden;margin:0 auto;outline:none" tabindex="0" title="">
#          <svg height="200" preserveaspectratio="xMidYMid slice" style="width: 100%; height: 100%; transform: translate3d(0px, 0px, 0px);" viewbox="0 0 800 200" width="800" xmlns="http://www.w3.org/2000/svg">
#           <defs>
#            <clippath id="__lottie_element_2">
#             <rect height="200" width="800" x="0" y="0">
#             </rect>
#            </clippath>
#            <clippath id="__lottie_element_5">
#             <path clip-rule="nonzero" d=" M1483,-169.51800537109375 C1483,-169.51800537109375 -49,-169.51800537109375 -49,-169.51800537109375 C-49,-169.51800537109375 -49,42.481998443603516 -49,42.481998443603516 C-49,42.481998443603516 1483,42.481998443603516 1483,42.481998443603516 C1483,42.481998443603516 1483,-169.51800537109375 1483,-169.51800537109375" fill="#ffffff" fill-opacity="1">
#             </path>
#             <path clip-rule="nonzero" d=" M1567,37.731998443603516 C1567,37.731998443603516 -41,37.731998443603516 -41,37.731998443603516 C-41,37.731998443603516 -41,176.48199462890625 -41,176.48199462890625 C-41,176.48199462890625 1567,176.48199462890625 1567,176.48199462890625 C1567,176.48199462890625 1567,37.731998443603516 1567,37.731998443603516" fill="#ffffff" fill-opacity="1">
#             </path>
#            </clippath>
#           </defs>
#           <g clip-path="url(#__lottie_element_2)">
# de _" clip-path="url(#__lottie_element_5)" fill="rgb(255,255,255)" font-family="Montserrat" font-size="74" font-style="normal" font-weight="200" opacity="1" style="display: block;" transform="matrix(1,0,0,1,10.079000473022461,75.30699920654297)">
#             <path d=" M48.89,0 C48.89,0 50.6,0 50.6,0 C50.6,0 26.38,-52.17 26.38,-52.17 C26.38,-52.17 24.89,-52.17 24.89,-52.17 C24.89,-52.17 0.67,0 0.67,0 C0.67,0 2.39,0 2.39,0 C2.39,0 9.69,-15.72 9.69,-15.72 C9.69,-15.72 41.58,-15.72 41.58,-15.72 C41.58,-15.72 48.89,0 48.89,0z M10.36,-17.14 C10.36,-17.14 25.64,-50.15 25.64,-50.15 C25.64,-50.15 40.91,-17.14 40.91,-17.14 C40.91,-17.14 10.36,-17.14 10.36,-17.14z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,0,0)">
#             </path>
#             <path d=" M27.28,-38.75 C19.23,-38.75 12.67,-34.06 10.06,-26.75 C10.06,-26.75 10.06,-38.53 10.06,-38.53 C10.06,-38.53 8.57,-38.53 8.57,-38.53 C8.57,-38.53 8.57,14.46 8.57,14.46 C8.57,14.46 10.06,14.46 10.06,14.46 C10.06,14.46 10.06,-11.7 10.06,-11.7 C12.67,-4.47 19.23,0.22 27.28,0.22 C37.86,0.22 45.98,-7.83 45.98,-19.23 C45.98,-30.63 37.86,-38.75 27.28,-38.75z M27.28,-1.19 C17.44,-1.19 10.06,-8.57 10.06,-19.23 C10.06,-29.88 17.44,-37.34 27.28,-37.34 C37.11,-37.34 44.49,-29.88 44.49,-19.23 C44.49,-8.57 37.11,-1.19 27.28,-1.19z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: inherit;" transform="matrix(1,0,0,1,50.172000885009766,0)">
#             </path>
#             <path d=" M10.06,-28.54 C10.06,-28.54 10.06,-38.53 10.06,-38.53 C10.06,-38.53 8.57,-38.53 8.57,-38.53 C8.57,-38.53 8.57,0 8.57,0 C8.57,0 10.06,0 10.06,0 C10.06,0 10.06,-20
-38.75 4.02,-30.7 4.02,-19.3 C4.02,-7.9 12.15,0.22 22.73,0.22 C30.78,0.22 37.34,-4.47 39.94,-11.77 C39.94,-11.77 39.94,0 39.94,0 C39.94,0 41.44,0 41.44,0 C41.44,0 41.44,-55.3 41.44,-55.3 C41.44,-55.3 39.94,-55.3 39.94,-55.3z M22.73,-1.19 C12.89,-1.19 5.51,-8.64 5.51,-19.3 C5.51,-29.96 12.89,-37.34 22.73,-37.34 C32.57,-37.34 39.94,-29.96 39.94,-19.3 C39.94,-8.64 32.57,-1.19 22.73,-1.19z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: none;" transform="matrix(1,0,0,1,306.4339904785156,103)">
#             </path>
#             <path d=" M39.72,-19.67 C39.72,-30.85 31.97,-38.75 21.84,-38.75 C11.63,-38.75 4.02,-30.7 4.02,-19.3 C4.02,-7.9 12.15,0.22 23.25,0.22 C28.77,0.22 33.98,-1.94 37.41,-6.11 C37.41,-6.11 36.37,-7.15 36.37,-7.15 C33.31,-3.13 28.39,-1.19 23.25,-1.19 C13.04,-1.19 5.44,-8.64 5.44,-19.3 C5.44,-19.3 39.72,-19.3 39.72,-19.3 C39.72,-19.3 39.72,-19.67 39.72,-19.67z M21.84,-37.34 C30.93,-37.34 37.78,-30.26 38.31,-20.72 C38.31,-20.72 5.44,-20.72 5.44,-20.72 C5.96,-30.26 12.74,-37.34 21.84,-37.34z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: none;" transform="matrix(1,0,0,1,355.3479919433594,103)">
#             </path>
#             <path d=" M6.78,0.22 C7.82,0.22 8.72,-0.67 8.72,-1.71 C8.72,-2.76 7.82,-3.65 6.78,-3.65 C5.74,-3.65 4.84,-2.76 4.84,-1.71 C4.84,-0.67 5.74,0.22 6.78,0.22z" fill="rgb(255,255,255)" opacity="1" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: none;" transform="matrix(1,0,0,1,398.0460205078125,103)">
#             </path>
#             <path d=" M0,1.42 C0,1.42 37.26,1.42 37.26,1.42 C37.26,1.42 37.26,0 37.26,0 C37.26,0 0,0 0,0 C0,0 0,1.42 0,1.42z" fill="rgb(255,255,255)" opacity="0.38000000000000256" stroke-linecap="butt" stroke-linejoin="round" stroke-miterlimit="4" style="display: none;" transform="matrix(1,0,0,1,410.77398681640625,103)">
#             </path>
#            </g>
#           </g>
#          </svg>
#         </div>
#        </div>
#        <div class="headerTitle">
#         Vamos muito além de um diploma,
#         <br/>
#         te preparamos para o mundo real.
#         <br/>
#         Conheça nossas trilhas de
#         <br/>
#         <b>
#          Data Science
#         </b>
#         e
#         <b>
#          Web Full Stack
#         </b>
#         .
#        </div>
#        <div class="styles__Container-sc-1djgj8m-0 fDyYQY">
#         <div>
#          <button class="btn__header btn__primary btn__primary__active">
#           Comece agora
#          </button>
#         </div>
#        </div>
#       </div>
#       <div class="homeImage">
#        <div style="display:block;overflow:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;margin:0">
#         <img decoding="async" sizes="100vw" src="/_next/image?url=%2Fimages%2FbackgroundHeaderHome.png&amp;w=3840&amp;q=75" srcset="/_next/image?url=%2Fimages%2FbackgroundHeaderHome.png&amp;w=640&amp;q=75 640w, /_next/image?url=%2Fimages%2FbackgroundHeaderHome.png&amp;w=750&amp;q=75 750w, /_next/image?url=%2Fimages%2FbackgroundHeaderHome.png&amp;w=828&amp;q=75 828w, /_next/image?url=%2Fimages%2FbackgroundHeaderHome.png&amp;w=1080&amp;q=75 1080w, /_next/image?url=%2Fimages%2FbackgroundHeaderHome.png&amp;w=1200&amp;q=75 1200w, /_next/image?url=%2Fimages%2FbackgroundHeaderHome.png&amp;w=1920&amp;q=75 1920w, /_next/image?url=%2Fimages%2FbackgroundHeaderHome.png&amp;w=2048&amp;q=75 2048w, /_next/image?url=%2Fimages%2FbackgroundHeaderHome.png&amp;w=3840&amp;q=75 3840w" style="visibility: inherit; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#        </div>
#       </div>
#      </div>
#     </section>
#    </div>
#   </div>
#   <div class="homeSliderContainer__Container-sc-150npjf-0 gbLJyI">
#    <section id="slider">
#     <div class="slick-slider home__slider slick-initialized" dir="ltr">
#      <div class="slick-list">
#       <div class="slick-track" style="width: 9177px; opacity: 1; transform: translate3d(-1127px, 0px, 0px); transition: -webkit-transform 5200ms linear 0s;">
#        <div aria-hidden="true" class="slick-slide slick-cloned" data-index="-5" style="width: 161px;" tabindex="-1">
#         <div>
#          <div class="slider__img" style="width: 100%; display: inline-block;" tabindex="-1">
#           <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#            <div style="box-sizing: border-box; display: block; max-width: 100%;">
#             <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#            </div>
#            <img alt="ABCbrasil" decoding="async" src="..." style="visibility: hidden; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div aria-hidden="true" class="slick-slide slick-cloned" data-index="-4" style="width: 161px;" tabindex="-1">
#         <div>
#          <div class="slider__img" style="width: 100%; display: inline-block;" tabindex="-1">
#           <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#            <div style="box-sizing: border-box; display: block; max-width: 100%;">
#             <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#            </div>
#            <img alt="smiles" decoding="async" src="..." style="visibility: hidden; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div aria-hidden="true" class="slick-slide slick-cloned" data-index="-3" style="width: 161px;" tabindex="-1">
#         <div>
#          <div class="slider__img" style="width: 100%; display: inline-block;" tabindex="-1">
#           <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#            <div style="box-sizing: border-box; display: block; max-width: 100%;">
#             <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#            </div>
#            <img alt="aryzta" decoding="async" src="..." style="visibility: hidden; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div aria-hidden="true" class="slick-slide slick-cloned" data-index="-2" style="width: 161px;" tabindex="-1">
#         <div>
#          <div class="slider__img" style="width: 100%; display: inline-block;" tabindex="-1">
#           <div style="display: inline-block; max-width: 100%; overflow: hidden; position: relative; box-sizing: border-box; margin: 0px;">
#            <div style="box-sizing: border-box; display: block; max-width: 100%;">
#             <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width: 100%; display: block; margin: 0px; border: none; padding: 0px;"/>
#            </div>
#            <img alt="pio" decoding="async" src="..." style="visibility: hidden; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div aria-hidden="true" class="slick-slide slick-cloned" data-index="-1" style="width: 161px;" tabindex="-1">
#         <div>
#          <div class="slider__img" style="width:100%;display:inline-block" tabindex="-1">
#           <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#            <div style="box-sizing:border-box;display:block;max-width:100%">
#             <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#            </div>
#            <img alt="creditSuisse" decoding="async" src="..." style="visibility:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div aria-hidden="true" class="slick-slide" data-index="0" style="outline: none; width: 161px;" tabindex="-1">
#         <div>
#          <div class="slider__img" style="width:100%;display:inline-block" tabindex="-1">
#           <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#            <div style="box-sizing:border-box;display:block;max-width:100%">
#             <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#            </div>
#            <img alt="amazon" decoding="async" src="/_next/image?url=%2Fimages%2FamazonCinza.png&amp;w=384&amp;q=75" srcset="/_next/image?url=%2Fimages%2FamazonCinza.png&amp;w=256&amp;q=75 1x, /_next/image?url=%2Fimages%2FamazonCinza.png&amp;w=384&amp;q=75 2x" style="visibility: inherit; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div aria-hidden="true" class="slick-slide" data-index="1" style="outline: none; width: 161px;" tabindex="-1">
#         <div>
#          <div class="slider__img" style="width:100%;display:inline-block" tabindex="-1">
#           <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#            <div style="box-sizing:border-box;display:block;max-width:100%">
#             <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#            </div>
#            <img alt="bloomberg" decoding="async" src="/_next/image?url=%2Fimages%2FbloombergCinza.png&amp;w=384&amp;q=75" srcset="/_next/image?url=%2Fimages%2FbloombergCinza.png&amp;w=256&amp;q=75 1x, /_next/image?url=%2Fimages%2FbloombergCinza.png&amp;w=384&amp;q=75 2x" style="visibility: inherit; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div aria-hidden="false" class="slick-slide slick-active slick-current" data-index="2" style="outline: none; width: 161px;" tabindex="-1">
#         <div>
#          <div class="slider__img" style="width:100%;display:inline-block" tabindex="-1">
#           <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#            <div style="box-sizing:border-box;display:block;max-width:100%">
#             <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#            </div>
#            <img alt="stone" decoding="async" src="/_next/image?url=%2Fimages%2FstoneCinza.png&amp;w=384&amp;q=75" srcset="/_next/image?url=%2Fimages%2FstoneCinza.png&amp;w=256&amp;q=75 1x, /_next/image?url=%2Fimages%2FstoneCinza.png&amp;w=384&amp;q=75 2x" style="visibility: inherit; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div aria-hidden="false" class="slick-slide slick-active" data-index="3" style="outline: none; width: 161px;" tabindex="-1">
#         <div>
#          <div class="slider__img" style="width:100%;display:inline-block" tabindex="-1">
#           <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#            <div style="box-sizing:border-box;display:block;max-width:100%">
#             <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#            </div>
#            <img alt="empiricus" decoding="async" src="/_next/image?url=%2Fimages%2FempiricusCinza.png&amp;w=384&amp;q=75" srcset="/_next/image?url=%2Fimages%2FempiricusCinza.png&amp;w=256&amp;q=75 1x, /_next/image?url=%2Fimages%2FempiricusCinza.png&amp;w=384&amp;q=75 2x" style="visibility: inherit; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div aria-hidden="false" class="slick-slide slick-active" data-index="4" style="outline: none; width: 161px;" tabindex="-1">
#         <div>
#          <div class="slider__img" style="width:100%;display:inline-block" tabindex="-1">
#           <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#            <div style="box-sizing:border-box;display:block;max-width:100%">
#             <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#            </div>
#            <img alt="salesforce" decoding="async" src="/_next/image?url=%2Fimages%2FsalesforceCinza.png&amp;w=384&amp;q=75" srcset="/_next/image?url=%2Fimages%2FsalesforceCinza.png&amp;w=256&amp;q=75 1x, /_next/image?url=%2Fimages%2FsalesforceCinza.png&amp;w=384&amp;q=75 2x" style="visibility: inherit; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div aria-hidden="false" class="slick-slide slick-active" data-index="5" style="outline: none; width: 161px;" tabindex="-1">
#         <div>
#          <div class="slider__img" style="width:100%;display:inline-block" tabindex="-1">
#           <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#            <div style="box-sizing:border-box;display:block;max-width:100%">
#             <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#            </div>
#            <img alt="graded" decoding="async" src="/_next/image?url=%2Fimages%2FgradedCinza.png&amp;w=384&amp;q=75" srcset="/_next/image?url=%2Fimages%2FgradedCinza.png&amp;w=256&amp;q=75 1x, /_next/image?url=%2Fimages%2FgradedCinza.png&amp;w=384&amp;q=75 2x" style="visibility: inherit; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div aria-hidden="false" class="slick-slide slick-active" data-index="6" style="outline: none; width: 161px;" tabindex="-1">
#         <div>
#          <div class="slider__img" style="width:100%;display:inline-block" tabindex="-1">
#           <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#            <div style="box-sizing:border-box;display:block;max-width:100%">
#             <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#            </div>
#            <img alt="mobile" decoding="async" src="/_next/image?url=%2Fimages%2FmobileCinza.png&amp;w=384&amp;q=75" srcset="/_next/image?url=%2Fimages%2FmobileCinza.png&amp;w=256&amp;q=75 1x, /_next/image?url=%2Fimages%2FmobileCinza.png&amp;w=384&amp;q=75 2x" style="visibility: inherit; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: contain;"/>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div aria-hidden="true" class="slick-slide" data-index="7" style="outline: none; width: 161px;" tabindex="-1">
#         <div>
#          <div class="slider__img" style="width:100%;display:inline-block" tabindex="-1">
#           <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#            <div style="box-sizing:border-box;display:block;max-width:100%">
#             <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#            </div>
#            <img alt="xp" decoding="async" src="..." style="visibility:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div aria-hidden="true" class="slick-slide" data-index="8" style="outline: none; width: 161px;" tabindex="-1">
#         <div>
#          <div class="slider__img" style="width:100%;display:inline-block" tabindex="-1">
#           <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#            <div style="box-sizing:border-box;display:block;max-width:100%">
#             <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#            </div>
#            <img alt="chapel" decoding="async" src="..." style="visibility:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div aria-hidden="true" class="slick-slide" data-index="9" style="outline: none; width: 161px;" tabindex="-1">
#         <div>
#          <div class="slider__img" style="width:100%;display:inline-block" tabindex="-1">
#           <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#            <div style="box-sizing:border-box;display:block;max-width:100%">
#             <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#            </div>
# ...
#            </div>
#           </div>
#          </div>
#          <div aria-hidden="true" class="slick-slide slick-cloned" data-index="21" style="width: 158px;" tabindex="-1">
#           <div>
#            <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#             <div style="box-sizing:border-box;display:block;max-width:100%">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#             </div>
#             <img class="sobre-photo" decoding="async" src="..." style="visibility:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:fill;object-position:bottom" tabindex="-1"/>
#            </div>
#           </div>
#          </div>
#          <div aria-hidden="true" class="slick-slide slick-cloned" data-index="22" style="width: 158px;" tabindex="-1">
#           <div>
#            <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#             <div style="box-sizing:border-box;display:block;max-width:100%">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#             </div>
#             <img class="sobre-photo" decoding="async" src="..." style="visibility:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:fill;object-position:bottom" tabindex="-1"/>
#            </div>
#           </div>
#          </div>
#          <div aria-hidden="true" class="slick-slide slick-cloned" data-index="23" style="width: 158px;" tabindex="-1">
#           <div>
#            <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#             <div style="box-sizing:border-box;display:block;max-width:100%">
#              <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#             </div>
#             <img class="sobre-photo" decoding="async" src="..." style="visibility:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:fill;object-position:bottom" tabindex="-1"/>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <button class="slick-arrow slick-next" data-role="none" style="display:block" type="button">
#         <!-- -->
#         Next
#        </button>
#       </div>
#      </div>
#     </div>
#    </section>
#   </div>
#   <div class="styles__Container-xnhrx0-0 ldQCFj">
#    <div class="site-map">
#     <div class="site-map-content">
#      <div>
#       <h1>
#        TRILHA PYTHON &amp; DADOS
#       </h1>
#       <h2>
#        Quero me tornar um dev
#       </h2>
#       <a href="/pi/ds">
#        <p>
#         Data Science
#        </p>
#       </a>
#       <h2>
#        Quero aprender a programar
#       </h2>
#       <a href="/cursos/python_adulto">
#        <p>
#         Python
#        </p>
#       </a>
#       <a href="/cursos/ds_ia">
#        <p>
#         Data Science &amp; I.A
#        </p>
#       </a>
#       <a href="/cursos/python_finance">
#        <p>
#         Python For Finance
#        </p>
#       </a>
#       <a href="/cursos/banco-de-dados">
#        <p>
#         Banco De Dados
#        </p>
#       </a>
#       <a href="/curso-online/python-basics">
#        <p>
#         Online Python Basics
#        </p>
#       </a>
#       <a href="/curso-online/python-teens">
#        <p>
#         Python Teens
#        </p>
#       </a>
#      </div>
#      <div>
#       <h1>
#        TRILHA WEB FULL STACK
#       </h1>
#       <h2>
#        Quero me tornar um dev
#       </h2>
#       <a href="/pi/web">
#        <p>
#         Web Full Stack
#        </p>
#       </a>
#       <h2>
#        Quero aprender a programar
#       </h2>
#       <a href="/cursos/web-frontend-react">
#        <p>
#         Web Front-End &amp; React
#        </p>
#       </a>
#       <a href="/cursos/java">
#        <p>
#         Java
#        </p>
#       </a>
#       <a href="/curso-online/web-and-react">
#        <p>
#         Online Web &amp; React
#        </p>
#       </a>
#      </div>
#      <div>
#       <h1>
#        INSTITUCIONAL
#       </h1>
#       <a href="/certificado">
#        <p>
#         Certificados
#        </p>
#       </a>
#       <a href="/nosso-time">
#        <p>
#         Nosso Time
#        </p>
#       </a>
#       <a href="/blog">
#        <p>
#         Blog
#        </p>
#       </a>
#       <h1>
#        EVENTOS
#       </h1>
#       <a href="/coding_challenge">
#        <p>
#         Coding Challenge
#        </p>
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="styles__Container-sc-85gh8u-0 cUYoFM">
#   <footer class="site-footer">
#    <a class="footer-container-address" href="https://goo.gl/maps/CB3zVwyTvKfMfZTG8" target="_blank">
#     <svg fill="currentColor" height="40" role="img" stroke="currentColor" stroke-width="0" viewbox="0 0 24 24" width="40" xmlns="http://www.w3.org/2000/svg">
#      <title>
#      </title>
#      <path d="M19.527 4.799c1.212 2.608.937 5.678-.405 8.173-1.101 2.047-2.744 3.74-4.098 5.614-.619.858-1.244 1.75-1.669 2.727-.141.325-.263.658-.383.992-.121.333-.224.673-.34 1.008-.109.314-.236.684-.627.687h-.007c-.466-.001-.579-.53-.695-.887-.284-.874-.581-1.713-1.019-2.525-.51-.944-1.145-1.817-1.79-2.671L19.527 4.799zM8.545 7.705l-3.959 4.707c.724 1.54 1.821 2.863 2.871 4.18.247.31.494.622.737.936l4.984-5.925-.029.01c-1.741.601-3.691-.291-4.392-1.987a3.377 3.377 0 0 1-.209-.716c-.063-.437-.077-.761-.004-1.198l.001-.007zM5.492 3.149l-.003.004c-1.947 2.466-2.281 5.88-1.117 8.77l4.785-5.689-.058-.05-3.607-3.035zM14.661.436l-3.838 4.563a.295.295 0 0 1 .027-.01c1.6-.551 3.403.15 4.22 1.626.176.319.323.683.377 1.045.068.446.085.773.012 1.22l-.003.016 3.836-4.561A8.382 8.382 0 0 0 14.67.439l-.009-.003zM9.466 5.868L14.162.285l-.047-.012A8.31 8.31 0 0 0 11.986 0a8.439 8.439 0 0 0-6.169 2.766l-.016.018 3.665 3.084z">
#      </path>
#     </svg>
#     <b class="footer-text">
#      Av. Faria Lima, 1306 - 4º Andar - Pinheiros, SP
#     </b>
#    </a>
#    <div class="footer-logo">
#     <div class="footer-logo-container">
#      <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#       <div style="box-sizing:border-box;display:block;max-width:100%">
#        <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block;margin:0;border:none;padding:0"/>
#       </div>
#       <img alt="logoFooterBranco.png" decoding="async" src="..." style="visibility:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#      </div>
#      <div class="react-logo-wrapper">
#       <b class="footer-text footer-text-small">
#        Feito em React
#       </b>
#       <svg fill="currentColor" height="20" stroke="currentColor" stroke-width="0" viewbox="0 0 512 512" width="20" xmlns="http://www.w3.org/2000/svg">
#        <path d="M418.2 177.2c-5.4-1.8-10.8-3.5-16.2-5.1.9-3.7 1.7-7.4 2.5-11.1 12.3-59.6 4.2-107.5-23.1-123.3-26.3-15.1-69.2.6-112.6 38.4-4.3 3.7-8.5 7.6-12.5 11.5-2.7-2.6-5.5-5.2-8.3-7.7-45.5-40.4-91.1-57.4-118.4-41.5-26.2 15.2-34 60.3-23 116.7 1.1 5.6 2.3 11.1 3.7 16.7-6.4 1.8-12.7 3.8-18.6 5.9C38.3 196.2 0 225.4 0 255.6c0 31.2 40.8 62.5 96.3 81.5 4.5 1.5 9 3 13.6 4.3-1.5 6-2.8 11.9-4 18-10.5 55.5-2.3 99.5 23.9 114.6 27 15.6 72.4-.4 116.6-39.1 3.5-3.1 7-6.3 10.5-9.7 4.4 4.3 9 8.4 13.6 12.4 42.8 36.8 85.1 51.7 111.2 36.6 27-15.6 35.8-62.9 24.4-120.5-.9-4.4-1.9-8.9-3-13.5 3.2-.9 6.3-1.9 9.4-2.9 57.7-19.1 99.5-50 99.5-81.7 0-30.3-39.4-59.7-93.8-78.4zM282.9 92.3c37.2-32.4 71.9-45.1 87.7-36 16.9 9.7 23.4 48.9 12.8 100.4-.7 3.4-1.4 6.7-2.3 10-22.2-5-44.7-8.6-67.3-10.6-13-18.6-27.2-36.4-42.6-53.1 3.9-3.7 7.7-7.2 11.7-10.7zM167.2 307.5c5.1 8.7 10.3 17.4 15.8 25.9-15.6-1.7-31.1-4.2-46.4-7.5 4.4-14.4 9.9-29.3 16.3-44.5 4.6 8.8 9.3 17.5 14.3 26.1zm-30.3-120.3c14.4-3.2 29.7-5.8 45.6-7.8-5.3 8.3-10.5 16.8-15.4 25.4-4.9 8.5-9.7 17.2-14.2 26-6.3-14.9-11.6-29.5-16-43.6zm27.4 68.9c6.6-13.8 13.8-27.3 21.4-40.6s15.8-26.2 24.4-38.9c15-1.1 30.3-1.7 45.9-1.7s31 .6 45.9 1.7c8.5 12.6 16.6 25.5 24.3 38.7s14.9 26.7 21.7 40
viewbox="0 0 512 512" width="20" xmlns="http://www.w3.org/2000/svg">
#       <path d="M497.39 361.8l-112-48a24 24 0 0 0-28 6.9l-49.6 60.6A370.66 370.66 0 0 1 130.6 204.11l60.6-49.6a23.94 23.94 0 0 0 6.9-28l-48-112A24.16 24.16 0 0 0 122.6.61l-104 24A24 24 0 0 0 0 48c0 256.5 207.9 464 464 464a24 24 0 0 0 23.4-18.6l24-104a24.29 24.29 0 0 0-14.01-27.6z">
#       </path>
#      </svg>
#      <b class="footer-text">
#       11 2609-3807
#      </b>
#     </div>
#    </div>
#   </footer>
#  </div>
# </div>
# <script id="__NEXT_DATA__" type="application/json">
#  {"props":{"pageProps":{}},"page":"/","query":{},"buildId":"4PAjkTBmPxZT7XSDEmq7u","nextExport":true,"autoExport":true,"isFallback":false}
# </script>
# <script nomodule="" src="/_next/static/chunks/polyfills-ec9ce50fc97750c8259a.js">
# </script>
# <script async="" src="/_next/static/chunks/main-3a96d2b18bad6d0b4783.js">
# </script>
# <script async="" src="/_next/static/chunks/webpack-036661cb363135e955d5.js">
# </script>
# <script async="" src="/_next/static/chunks/framework.3ec84fece1faf180c1cb.js">
# </script>
# <script async="" src="/_next/static/chunks/1bfc9850.7ae5588ef687afbc58dc.js">
# </script>
# <script async="" src="/_next/static/chunks/d0447323.80494e444e37f2ed7c9b.js">
# </script>
# <script async="" src="/_next/static/chunks/b58d79c15998b100ca1bf94fc578c2cdd59be475.1e9f2b5c63a8a2647bf6.js">
# </script>
# <script async="" src="/_next/static/chunks/b73d3fb959f2a85d72f37f7777e7b8ae4d0e5fe8.00d3077f9c738422fab2.js">
# </script>
# <script async="" src="/_next/static/chunks/6dc053ff3f46209095ccaf21edfbb3593aa900a3.6f99c76369bd6c3eb4a7.js">
# </script>
# <script async="" src="/_next/static/chunks/6bf44b926a78aac2f5a1c497841f623ec5f526f5.0bae66b36cd2ddc783dd.js">
# </script>
# <script async="" src="/_next/static/chunks/0967251bc4bf133b03dce30facf16cc1a5e3dc3c.31d0a48df2bbd432f715.js">
# </script>
# <script async="" src="/_next/static/chunks/6afcf6667f7a5ea3a78a4341669129bd232c2338.b23f9dbcc446c78ddac9.js">
# </script>
# <script async="" src="/_next/static/chunks/f8aff9f05b7b980937e855c27783871945b050fc.b34ab0e163558c2012c0.js">
# </script>
# <script async="" src="/_next/static/chunks/pages/_app-91f8cbb1c06eafc39eb1.js">
# </script>
# <script async="" src="/_next/static/chunks/ea88be26.f2ab722fc5ee7e459d8e.js">
# </script>
# <script async="" src="/_next/static/chunks/2fec7d363034833beef7dc6e2c33e520a79817f0.3012610a1dbdd2ed650f.js">
# </script>
# <script async="" src="/_next/static/chunks/4b89fd5e19f3d52579ff3286fc85d6f45eb6dd12.56d7a9e1e3e4983e9503.js">
# </script>
# <script async="" src="/_next/static/chunks/28adfd4705ebf12c05b240dd8e25e75b2fa1c22a.e30d906d17adaf44a3e7.js">
# </script>
# <script async="" src="/_next/static/chunks/dfdf9f4bfbd2b46d8ba7af4089425ea7672499d3.73dbe72b5fad550f81cf.js">
# </script>
# <script async="" src="/_next/static/chunks/876f9bd84c75ff948539eb73d9e8542d39479d14.1d69a34f651aeb80da33.js">
# </script>
# <script async="" src="/_next/static/chunks/c62b1f5506a3d85383b562dbd5dbc47675d7d427.e83595660baa0f4e5ff2.js">
# </script>
# <script async="" src="/_next/static/chunks/pages/index-fe8b308a0d6a2f9d9536.js">
# </script>
# <script async="" src="/_next/static/4PAjkTBmPxZT7XSDEmq7u/_buildManifest.js">
# </script>
# <script async="" src="/_next/static/4PAjkTBmPxZT7XSDEmq7u/_ssgManifest.js">
# </script>
# <iframe id="_hjRemoteVarsFrame" name="_hjRemoteVarsFrame" src="https://vars.hotjar.com/box-5e3cec51ed8e99df6977c199d27812d7.html" style="display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;" title="_hjRemoteVarsFrame">
# </iframe>
# <script id="" type="text/javascript">
#  !function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","1571403226501915");fbq("track","PageView");
# </script>
# <noscript>
#  <img height="1" src="https://www.facebook.com/tr?id=1571403226501915&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <script id="" type="text/javascript">
#  _linkedin_partner_id="429257";window._linkedin_data_partner_ids=window._linkedin_data_partner_ids||[];window._linkedin_data_partner_ids.push(_linkedin_partner_id);
# </script>
# <script id="" type="text/javascript">
#  (function(){var b=document.getElementsByTagName("script")[0],a=document.createElement("script");a.type="text/javascript";a.async=!0;a.src="https://snap.licdn.com/li.lms-analytics/insight.min.js";b.parentNode.insertBefore(a,b)})();
# </script>
# <noscript>
#  <img alt="" height="1" src="https://px.ads.linkedin.com/collect/?pid=429257&amp;fmt=gif" style="display:none;" width="1"/>
# </noscript>
# <script src="/_next/static/chunks/pages/coding_challenge-b43b8c7ac00b98732254.js">
# </script>
# <script src="/_next/static/chunks/pages/lets-code-zero-1907fd309622c4c363ba.js">
# </script>
# <script src="/_next/static/chunks/9ec369c816e5693936b4ecee390e37b18c9e40ee.81ef1edfd8cfd5436864.js">
# </script>
# <script src="/_next/static/chunks/pages/certificado-d4266d9527291f4f2a3e.js">
# </script>
# <script src="/_next/static/chunks/pages/privacidade-d452805ea34cd9c7b618.js">
# </script>

# %% [markdown]
# Agora que temos o objeto do bs criado, podemos usar os métodos especiais deste objeto para extrair a informação que queremos!
#
# Lembrando que já descobrimos que queremos extrair os dados dentro da seguinte tag:
#
# `<a class='card__link'>`
#
# Pra isso, utilizaremos o método `.find()` ou `.find_all()`. Esses métodos suportam diversos argumentos para busca. Os mais comuns são:
#
# - Primeiro argumento posicional: A **tag HTML** que queremos extrair (no nosso caso, é a `a`).
# - O argumento nomeado "class_", que indica qual é a **classe CSS** que queremos extrair (no nosso caso, é a `card__link`)
#
# `.find()` vai retornar **a primeira aparição** da tag no HTML, enquanto `.find_all()` retorna **uma lista com as aparições**:

# %%
len(site.find_all('a', class_ = 'card__link'))
# Out:
# 6

# %%
# encontrando a tag desejada
total = site.find_all('a', class_ = 'card__link')[2]

total
# Out:
# <a class="card__link" href="/cursos/python_adulto"><div class="card trail__python"><div class="card__imagem__container"><div style="display:block;overflow:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;margin:0"><img alt="pythonCard.svg" decoding="async" name="Python" src="..." style="visibility:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/></div></div><div class="card__trail__icon"><div style="display:block;overflow:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;margin:0"><img alt="iconeTrilhaPython.svg" decoding="async" name="Python" src="..." style="visibility:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/></div></div><div class="card__text__container"><p class="card__text__title">Python</p><div class="card__text__desktop"><div><span style="font-weight:500">Pré-Requisito<p style="font-weight:400">Nenhum</p></span></div><div class="card__text__desktop__desc"><span style="font-weight:500">Carga Horária<p style="font-weight:400"><svg class="card__clock__icon desktop" height="19.45" viewbox="0 0 19.45 19.45" width="19.45" xmlns="http://www.w3.org/2000/svg"><g transform="translate(8.972 4.512)"><path class="a" d="M240.388,125.709l-2.712-2.034v-4.143a.753.753,0,1,0-1.507,0v4.52a.752.752,0,0,0,.3.6l3.013,2.26a.753.753,0,0,0,.9-1.205Z" transform="translate(-236.169 -118.779)"></path></g><path class="a" d="M9.725,0A9.725,9.725,0,1,0,19.45,9.725,9.736,9.736,0,0,0,9.725,0Zm0,17.944a8.219,8.219,0,1,1,8.219-8.219A8.229,8.229,0,0,1,9.725,17.944Z"></path></svg> <!-- -->48h</p></span></div></div></div></div></a>

# %% [markdown]
# É possível visualizar a extração de forma mais bonita, usando o método `.prettify()`:

# %%
print(total.prettify())
# Out:
# <a class="card__link" href="/cursos/python_adulto">
#  <div class="card trail__python">
#   <div class="card__imagem__container">
#    <div style="display:block;overflow:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;margin:0">
#     <img alt="pythonCard.svg" decoding="async" name="Python" src="..." style="visibility:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#    </div>
#   </div>
#   <div class="card__trail__icon">
#    <div style="display:block;overflow:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;margin:0">
#     <img alt="iconeTrilhaPython.svg" decoding="async" name="Python" src="..." style="visibility:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#    </div>
#   </div>
#   <div class="card__text__container">
#    <p class="card__text__title">
#     Python
#    </p>
#    <div class="card__text__desktop">
#     <div>
#      <span style="font-weight:500">
#       Pré-Requisito
#       <p style="font-weight:400">
#        Nenhum
#       </p>
#      </span>
#     </div>
#     <div class="card__text__desktop__desc">
#      <span style="font-weight:500">
#       Carga Horária
#       <p style="font-weight:400">
#        <svg class="card__clock__icon desktop" height="19.45" viewbox="0 0 19.45 19.45" width="19.45" xmlns="http://www.w3.org/2000/svg">
#         <g transform="translate(8.972 4.512)">
#          <path class="a" d="M240.388,125.709l-2.712-2.034v-4.143a.753.753,0,1,0-1.507,0v4.52a.752.752,0,0,0,.3.6l3.013,2.26a.753.753,0,0,0,.9-1.205Z" transform="translate(-236.169 -118.779)">
#          </path>
#         </g>
#         <path class="a" d="M9.725,0A9.725,9.725,0,1,0,19.45,9.725,9.736,9.736,0,0,0,9.725,0Zm0,17.944a8.219,8.219,0,1,1,8.219-8.219A8.229,8.229,0,0,1,9.725,17.944Z">
#         </path>
#        </svg>
#        <!-- -->
#        48h
#       </p>
#      </span>
#     </div>
#    </div>
#   </div>
#  </div>
# </a>

# %% [markdown]
# Como extraímos agora as informações que queremos (título do curso, pré-requisitos e link)?
#
# O atributo `.text` retorna **apenas os textos** do objeto sopa em forma de string, sem as Tags.
#
# Com isso, é possível selecionar todaa informação que queremos! Mas, com alguns detalhes...

# %%
total.text
# Out:
# 'PythonPré-RequisitoNenhumCarga Horária 48h'

# %% [markdown]
# Identificamos as seguintes tags:
#
# - Titulo do curso:
#
# ```html
# <p class="card__text__title">
# ```
#
# - Pré-requisitos
#
# ```html
# <div class="card__text__desktop">
#     <div>
#         <span style="font-weight:500">
#             ...
#             <p style="font-weight:400">
#                 Nenhum
#             </p>
#          </span>
#     </div>
#     ...
# </div>
# ```
#
# - Carga horária:
#
# ```html
# <div class="card__text__desktop__desc">
#     <span style="font-weight:500">
#         ...
#         <p style="font-weight:400">
#             ...
#             48h
#         </p>
#     </span>
# </div>
# ```
#
#
# Vamos criar objetos pra essas tags:

# %%
titulo = total.find('p', class_ = 'card__text__title')

print(titulo.prettify())
# Out:
# <p class="card__text__title">
#  Python
# </p>

# %%
requisitos = (
    total
    .find('div', class_ = 'card__text__desktop')
    .div
    .span
    .p)

print(requisitos.prettify())
# Out:
# <p style="font-weight:400">
#  Nenhum
# </p>

# %%
horario = (
    total
    .find('div', class_ = 'card__text__desktop__desc')
    .span
    .p
)

print(horario.prettify())
# Out:
# <p style="font-weight:400">
#  <svg class="card__clock__icon desktop" height="19.45" viewbox="0 0 19.45 19.45" width="19.45" xmlns="http://www.w3.org/2000/svg">
#   <g transform="translate(8.972 4.512)">
#    <path class="a" d="M240.388,125.709l-2.712-2.034v-4.143a.753.753,0,1,0-1.507,0v4.52a.752.752,0,0,0,.3.6l3.013,2.26a.753.753,0,0,0,.9-1.205Z" transform="translate(-236.169 -118.779)">
#    </path>
#   </g>
#   <path class="a" d="M9.725,0A9.725,9.725,0,1,0,19.45,9.725,9.736,9.736,0,0,0,9.725,0Zm0,17.944a8.219,8.219,0,1,1,8.219-8.219A8.229,8.229,0,0,1,9.725,17.944Z">
#   </path>
#  </svg>
#  <!-- -->
#  48h
# </p>

# %% [markdown]
# Vamos pegar o atributo text de cada um:

# %%
print('Titulo:', titulo.text)
print('Requisitos:', requisitos.text)
print('Horario:', horario.text)
# Out:
# Titulo: Python
# Requisitos: Nenhum
# Horario:  48h

# %% [markdown]
# Agora só falta pegar o link!
#
# Para fazer isso, identificamos que o link é o que já está com a tag `<a class="card__link" href="/cursos/python_adulto">`
#
# Neste caso, o link está dentro da própria tag, com o parâmetro `href`
#
# > Note que o `href` é `/cursos/python_adulto`. Mas o link completo deve conter também o domnínio-base do site, que nada mais é do que o que vem antes da barra: `https://letscode-academy.com`.
#
# > Assim, o link completo é: `https://letscode-academy.com/cursos/python_adulto`
#
# Como o link está dentro da tag, sua extração **não é com o `.text`**, mas sim utilizando uma estrutura de dicionário:

# %%
print(total.prettify())
# Out:
# <a class="card__link" href="/cursos/python_adulto">
#  <div class="card trail__python">
#   <div class="card__imagem__container">
#    <div style="display:block;overflow:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;margin:0">
#     <img alt="pythonCard.svg" decoding="async" name="Python" src="..." style="visibility:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#    </div>
#   </div>
#   <div class="card__trail__icon">
#    <div style="display:block;overflow:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;margin:0">
#     <img alt="iconeTrilhaPython.svg" decoding="async" name="Python" src="..." style="visibility:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/>
#    </div>
#   </div>
#   <div class="card__text__container">
#    <p class="card__text__title">
#     Python
#    </p>
#    <div class="card__text__desktop">
#     <div>
#      <span style="font-weight:500">
#       Pré-Requisito
#       <p style="font-weight:400">
#        Nenhum
#       </p>
#      </span>
#     </div>
#     <div class="card__text__desktop__desc">
#      <span style="font-weight:500">
#       Carga Horária
#       <p style="font-weight:400">
#        <svg class="card__clock__icon desktop" height="19.45" viewbox="0 0 19.45 19.45" width="19.45" xmlns="http://www.w3.org/2000/svg">
#         <g transform="translate(8.972 4.512)">
#          <path class="a" d="M240.388,125.709l-2.712-2.034v-4.143a.753.753,0,1,0-1.507,0v4.52a.752.752,0,0,0,.3.6l3.013,2.26a.753.753,0,0,0,.9-1.205Z" transform="translate(-236.169 -118.779)">
#          </path>
#         </g>
#         <path class="a" d="M9.725,0A9.725,9.725,0,1,0,19.45,9.725,9.736,9.736,0,0,0,9.725,0Zm0,17.944a8.219,8.219,0,1,1,8.219-8.219A8.229,8.229,0,0,1,9.725,17.944Z">
#         </path>
#        </svg>
#        <!-- -->
#        48h
#       </p>
#      </span>
#     </div>
#    </div>
#   </div>
#  </div>
# </a>

# %%
# acessando o "href", passando como chave de um dicionário:
link = total['href']

link
# Out:
# '/cursos/python_adulto'

# %%
# pra ter o endereço completo, precisamos concatenar com o dominio base do site:
texto_link = "https://letscode.com.br" + link

texto_link
# Out:
# 'https://letscode.com.br/cursos/python_adulto'

# %% [markdown]
# Agora sim! Temos extraídos:

# %%
print('Titulo:', titulo.text)
print('Requisitos:', requisitos.text)
print('Horario:', horario.text)
# Out:
# Titulo: Python
# Requisitos: Nenhum
# Horario:  48h

# %% [markdown]
# Vamos juntar tudo agora:

# %%
from selenium import webdriver
import bs4

#######################################################
# fazendo a requisição
# e criando o objeto sopa de todo o site

driver = webdriver.Chrome('chromedriver')
driver.get("http://letscode-academy.com/")
element = driver.find_element_by_tag_name('body')
resposta = element.get_attribute('innerHTML') 

site = bs4.BeautifulSoup(resposta, 'html.parser')

#######################################################
# pegando apenas a tag que nos interessa, e o texto

total = site.find_all('a', class_ = 'card__link')[2]

#######################################################
# separando os sub-elementos da tag, e ja transformando em texto

titulo = (
    total
    .find('p', class_ = 'card__text__title')
    .text
)

requisitos = (
    total
    .find('div', class_ = 'card__text__desktop')
    .div
    .span
    .p
    .text)

horario = (
    total
    .find('div', class_ = 'card__text__desktop__desc')
    .span
    .p
    .text
)

lista = [titulo, requisitos, horario]

# %%
lista
# Out:
# ['Python', 'Nenhum', ' 48h']

# %% [markdown]
# Perfeito!
#
# Agora que sabemos exatamente o que queremos extrair, usando a primeira aparição, vamos fazer o mesmo pra **todas as aparições**.
#
# Mas, antes, vamos organizar o nosso código que faz a extração das infomações de 1 curso em uma função para facilitar o nosso trabalho daqui para frente:

# %%
def extrai_curso(tag):
    titulo = (
        tag
        .find('p', class_ = 'card__text__title')
        .text
    )

    requisitos = (
        tag
        .find('div', class_ = 'card__text__desktop')
        .div
        .span
        .p
        .text)

    horario = (
        tag
        .find('div', class_ = 'card__text__desktop__desc')
        .span
        .p
        .text
    )

    return [titulo, requisitos, horario]

# %%
extrai_curso(total)
# Out:
# ['Python', 'Nenhum', ' 48h']

# %%
from selenium import webdriver
import bs4

#######################################################
# fazendo a requisição
# e criando o objeto sopa de todo o site

# driver = webdriver.Chrome('chromedriver')
# driver.get("http://letscode-academy.com/")
# element = driver.find_element_by_tag_name('body')
# resposta = element.get_attribute('innerHTML') 

# site = bs4.BeautifulSoup(resposta, 'html.parser')

#######################################################
# pegando apenas a tag que nos interessa, e o texto

# agora temos uma lista com todas as aparições da tag!
total_todos = site.find_all('a', class_ = 'card__link')

# vamos fazer uma lista de listas com titulo, pre_faixa e link
lista_todos = []

for total in total_todos:
    lista = extrai_curso(total)
    lista_todos.append(lista)
    
lista_todos
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-8c52a06ca011> in <module>
#      23
#      24 for total in total_todos:
# ---> 25     lista = extrai_curso(total)
#      26     lista_todos.append(lista)
#      27
#
# <ipython-input-27-4bf98e0d7cdf> in extrai_curso(tag)
#       7
#       8     requisitos = (
# ----> 9         tag
#      10         .find('div', class_ = 'card__text__desktop')
#      11         .div
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %% [markdown]
# Tentando entender pq aconteceu o erro...

# %%
# %debug
# Out:
# > <ipython-input-27-4bf98e0d7cdf>(9)extrai_curso()
#       7
#       8     requisitos = (
# ----> 9         tag
#      10         .find('div', class_ = 'card__text__desktop')
#      11         .div
#
# ipdb> tag
# <a class="card__link" href="/pi/ds"><div class="card trail__python card__pi"><div class="card__imagem__container"><div style="display:block;overflow:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;margin:0"><img alt="piHome.svg" decoding="async" name="Pi Data Science" src="..." style="visibility:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/></div></div><div class="card__trail__icon"><div style="display:block;overflow:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;margin:0"><img alt="iconeTrilhaPython.svg" decoding="async" name="Pi Data Science" src="..." style="visibility:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain"/></div></div><div class="card__text__container"><p class="card__text__title">Pi Data Science</p><p class="card__text__desc">MINI <b>FACULDADE</b></p><p class="card__text__desc"><svg class="card__clock__icon pi desktop" height="19.45" viewbox="0 0 19.45 19.45" width="19.45" xmlns="http://www.w3.org/2000/svg"><g transform="translate(8.972 4.512)"><path class="a" d="M240.388,125.709l-2.712-2.034v-4.143a.753.753,0,1,0-1.507,0v4.52a.752.752,0,0,0,.3.6l3.013,2.26a.753.753,0,0,0,.9-1.205Z" transform="translate(-236.169 -118.779)"></path></g><path class="a" d="M9.725,0A9.725,9.725,0,1,0,19.45,9.725,9.736,9.736,0,0,0,9.725,0Zm0,17.944a8.219,8.219,0,1,1,8.219-8.219A8.229,8.229,0,0,1,9.725,17.944Z"></path></svg> <!-- -->900h</p></div></div></a>
# ipdb> q

# %%
print(total.prettify())

# %% [markdown]
# Vamos então adicionar genenciamento de errors ao nosso código.
#
# Nos casos em que houver um erro, vamos adicionar "Não disponível" ao campo

# %%
def extrai_curso(tag):
    titulo = (
        tag
        .find('p', class_ = 'card__text__title')
        .text
    )

    ...

# %%
def extrai_curso(tag):
    try:
        titulo = (
            tag
            .find('p', class_ = 'card__text__title')
            .text
        )
    except Exception as ex:
        titulo = 'Não disponivel'

    try:
        requisitos = (
            tag
            .find('div', class_ = 'card__text__desktop')
            .div
            .span
            .p
            .text)
    except Exception as ex:
        requisitos = 'Não disponivel'
    
    try: 
        horario = (
            tag
            .find('div', class_ = 'card__text__desktop__desc')
            .span
            .p
            .text
        )
    except Exception as ex:
        horario = 'Não disponivel'

    return [titulo, requisitos, horario]

# %%
from selenium import webdriver
import bs4

#######################################################
# fazendo a requisição
# e criando o objeto sopa de todo o site

# driver = webdriver.Chrome('chromedriver')
# driver.get("http://letscode-academy.com/")
# element = driver.find_element_by_tag_name('body')
# resposta = element.get_attribute('innerHTML') 

# site = bs4.BeautifulSoup(resposta, 'html.parser')

#######################################################
# pegando apenas a tag que nos interessa, e o texto

# agora temos uma lista com todas as aparições da tag!
total_todos = site.find_all('a', class_ = 'card__link')

# vamos fazer uma lista de listas com titulo, pre_faixa e link
lista_todos = []

for total in total_todos:

    lista = extrai_curso(total)
    lista_todos.append(lista)
    
lista_todos
# Out:
# [['Pi Data Science', 'Não disponivel', 'Não disponivel'],
#  ['Pi Web Full Stack', 'Não disponivel', 'Não disponivel'],
#  ['Python', 'Nenhum', ' 48h'],
#  ['Web Front-End & React', 'Nenhum', ' 72h'],
#  ['Data Science & I.A.', 'Python', ' 72h'],
#  ['Java', 'Nenhum', ' 72h']]

# %% [markdown]
# Mas espera. Tem muito mais curso oferecido na Let\`s Code! Então qual o problema?
#
# Note que na pagina nem todos os cursos são carregados. Temos que clicar no botão "Mais Cursos" para que eles sejam exibidos.
#
# Vamos clickar usando o Selenium:

# %%
driver = webdriver.Chrome('chromedriver')
driver.get("http://letscode-academy.com/")

# %%
btn = driver.find_element_by_class_name(
    'btn__maiscursos')
btn.click()

# %%
from selenium import webdriver
import bs4
import time
#######################################################
# fazendo a requisição
# e criando o objeto sopa de todo o site

driver = webdriver.Chrome('chromedriver')
driver.get("http://letscode-academy.com/")

btn = driver.find_element_by_class_name('btn__maiscursos')
btn.click()

element = driver.find_element_by_tag_name('body')
resposta = element.get_attribute('innerHTML') 

site = bs4.BeautifulSoup(resposta, 'html.parser')

#######################################################
# pegando apenas a tag que nos interessa, e o texto

# agora temos uma lista com todas as aparições da tag!
total_todos = site.find_all('a', class_ = 'card__link')

# vamos fazer uma lista de listas com titulo, pre_faixa e link
lista_todos = []

for total in total_todos:

    lista = extrai_curso(total)
    lista_todos.append(lista)
    
lista_todos
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-38-fbfc9f872181> in <module>
#      10
#      11 btn = driver.find_element_by_class_name('btn__maiscursos')
# ---> 12 btn.click()
#      13
#      14 element = driver.find_element_by_tag_name('body')
#
# ~/anaconda3/envs/dpr/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~/anaconda3/envs/dpr/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/anaconda3/envs/dpr/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/envs/dpr/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementClickInterceptedException: Message: element click intercepted: Element is not clickable at point (521, 2231)
#   (Session info: chrome=89.0.4389.114)

# %% [markdown]
# Parece que precisamos rolar a pagina até o botão

# %%
from selenium import webdriver
import bs4
import time
#######################################################
# fazendo a requisição
# e criando o objeto sopa de todo o site

driver = webdriver.Chrome('chromedriver')
driver.get("http://letscode-academy.com/")

btn = driver.find_element_by_class_name('btn__maiscursos')

driver.execute_script(f"window.scrollTo(0, {btn.location['y'] - 200})") 
time.sleep(1)

btn.click()

element = driver.find_element_by_tag_name('body')
resposta = element.get_attribute('innerHTML') 

site = bs4.BeautifulSoup(resposta, 'html.parser')

#######################################################
# pegando apenas a tag que nos interessa, e o texto

# agora temos uma lista com todas as aparições da tag!
total_todos = site.find_all('a', class_ = 'card__link')

# vamos fazer uma lista de listas com titulo, pre_faixa e link
lista_todos = []

for total in total_todos:

    lista = extrai_curso(total)
    lista_todos.append(lista)
    
lista_todos
# Out:
# [['Pi Data Science', 'Não disponivel', 'Não disponivel'],
#  ['Pi Web Full Stack', 'Não disponivel', 'Não disponivel'],
#  ['Python', 'Nenhum', ' 48h'],
#  ['Web Front-End & React', 'Nenhum', ' 72h'],
#  ['Data Science & I.A.', 'Python', ' 72h'],
#  ['Java', 'Nenhum', ' 72h'],
#  ['Python For Finance', 'Python', ' 24h'],
#  ['Banco De Dados', 'Nenhum', ' 24h'],
#  ['Online Python Basics', 'Nenhum', ' 10h'],
#  ['Online Web & React', 'Nenhum', ' 10h'],
#  ['Python Teens', 'Nenhum', ' 20h']]

# %% [markdown]
# Agora que temos nossa lista de listas, podemos escrevê-la pra um arquivo da maneira que quisermos

# %% [markdown]
# #### Usando o Pandas

# %%
import pandas as pd

df = pd.DataFrame(lista_todos, columns=['Nome', 'Pré-requisito', 'Carga Horária'])

display(df)

df.to_excel("cursos_LC.xlsx")
# Out:
#                      Nome   Pré-requisito   Carga Horária
# 0         Pi Data Science  Não disponivel  Não disponivel
# 1       Pi Web Full Stack  Não disponivel  Não disponivel
# 2                  Python          Nenhum             48h
# 3   Web Front-End & React          Nenhum             72h
# 4     Data Science & I.A.          Python             72h
# 5                    Java          Nenhum             72h
# 6      Python For Finance          Python             24h
# 7          Banco De Dados          Nenhum             24h
# 8    Online Python Basics          Nenhum             10h
# 9      Online Web & React          Nenhum             10h
# 10           Python Teens          Nenhum             20h

# %% [markdown]
# ___
# ___
# ## Objeto sopa com XML
# ___
# ___

# %%
import requests
requests.get("http://servicos.cptec.inpe.br/XML/listaCidades?city=sao paulo").text
# Out:
# "<?xml version='1.0' encoding='ISO-8859-1'?><cidades><cidade><nome>São Paulo</nome><uf>SP</uf><id>244</id></cidade><cidade><nome>São Paulo das Missões</nome><uf>RS</uf><id>5019</id></cidade><cidade><nome>São Paulo de Olivença</nome><uf>AM</uf><id>5020</id></cidade><cidade><nome>São Paulo do Potengi</nome><uf>RN</uf><id>5021</id></cidade></cidades>"

# %%
import requests
resposta = requests.get("http://servicos.cptec.inpe.br/XML/listaCidades?city=sao paulo")

sopa = bs4.BeautifulSoup(resposta.text, 'lxml')

print(sopa.html.prettify())
# Out:
# <html>
#  <body>
#   <cidades>
#    <cidade>
#     <nome>
#      São Paulo
#     </nome>
#     <uf>
#      SP
#     </uf>
#     <id>
#      244
#     </id>
#    </cidade>
#    <cidade>
#     <nome>
#      São Paulo das Missões
#     </nome>
#     <uf>
#      RS
#     </uf>
#     <id>
#      5019
#     </id>
#    </cidade>
#    <cidade>
#     <nome>
#      São Paulo de Olivença
#     </nome>
#     <uf>
#      AM
#     </uf>
#     <id>
#      5020
#     </id>
#    </cidade>
#    <cidade>
#     <nome>
#      São Paulo do Potengi
#     </nome>
#     <uf>
#      RN
#     </uf>
#     <id>
#      5021
#     </id>
#    </cidade>
#   </cidades>
#  </body>
# </html>

# %%
sopa.id
# Out:
# <id>244</id>

# %%
codigo = 244
url = f'http://servicos.cptec.inpe.br/XML/cidade/{codigo}/previsao.xml'

resposta = requests.get(url)

resposta
# Out:
# <Response [200]>

# %%
resposta.headers
# Out:
# {'Date': 'Tue, 13 Apr 2021 00:36:43 GMT', 'Cache-Control': 'no-cache', 'Content-Type': 'text/xml', 'Access-Control-Allow-Origin': '*', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Content-Length': '217', 'Keep-Alive': 'timeout=10, max=10000', 'Connection': 'Keep-Alive'}

# %%
resposta.text
# Out:
# "<?xml version='1.0' encoding='ISO-8859-1'?><cidade><nome>São Paulo</nome><uf>SP</uf><atualizacao>2021-04-12</atualizacao><previsao><dia>2021-04-13</dia><tempo>ci</tempo><maxima>21</maxima><minima>17</minima><iuv>8.0</iuv></previsao><previsao><dia>2021-04-14</dia><tempo>pn</tempo><maxima>23</maxima><minima>14</minima><iuv>8.0</iuv></previsao><previsao><dia>2021-04-15</dia><tempo>n</tempo><maxima>25</maxima><minima>16</minima><iuv>8.0</iuv></previsao><previsao><dia>2021-04-16</dia><tempo>n</tempo><maxima>25</maxima><minima>15</minima><iuv>8.0</iuv></previsao></cidade>"

# %%
site = bs4.BeautifulSoup(resposta.text, 'lxml')

print(site.html.prettify())
# Out:
# <html>
#  <body>
#   <cidade>
#    <nome>
#     São Paulo
#    </nome>
#    <uf>
#     SP
#    </uf>
#    <atualizacao>
#     2021-04-12
#    </atualizacao>
#    <previsao>
#     <dia>
#      2021-04-13
#     </dia>
#     <tempo>
#      ci
#     </tempo>
#     <maxima>
#      21
#     </maxima>
#     <minima>
#      17
#     </minima>
#     <iuv>
#      8.0
#     </iuv>
#    </previsao>
#    <previsao>
#     <dia>
#      2021-04-14
#     </dia>
#     <tempo>
#      pn
#     </tempo>
#     <maxima>
#      23
#     </maxima>
#     <minima>
#      14
#     </minima>
#     <iuv>
#      8.0
#     </iuv>
#    </previsao>
#    <previsao>
#     <dia>
#      2021-04-15
#     </dia>
#     <tempo>
#      n
#     </tempo>
#     <maxima>
#      25
#     </maxima>
#     <minima>
#      16
#     </minima>
#     <iuv>
#      8.0
#     </iuv>
#    </previsao>
#    <previsao>
#     <dia>
#      2021-04-16
#     </dia>
#     <tempo>
#      n
#     </tempo>
#     <maxima>
#      25
#     </maxima>
#     <minima>
#      15
#     </minima>
#     <iuv>
#      8.0
#     </iuv>
#    </previsao>
#   </cidade>
#  </body>
# </html>

# %%
site.nome
# Out:
# <nome>São Paulo</nome>

# %%
site.nome.text

# %%
site.previsao

# %%
site.previsao.dia

# %%
site.find_all("previsao")
# Out:
# [<previsao><dia>2021-04-13</dia><tempo>ci</tempo><maxima>21</maxima><minima>17</minima><iuv>8.0</iuv></previsao>,
#  <previsao><dia>2021-04-14</dia><tempo>pn</tempo><maxima>23</maxima><minima>14</minima><iuv>8.0</iuv></previsao>,
#  <previsao><dia>2021-04-15</dia><tempo>n</tempo><maxima>25</maxima><minima>16</minima><iuv>8.0</iuv></previsao>,
#  <previsao><dia>2021-04-16</dia><tempo>n</tempo><maxima>25</maxima><minima>15</minima><iuv>8.0</iuv></previsao>]

# %%
cidade = site.nome.text
print("Cidade:", cidade)

for previsao in site.find_all("previsao"):
    
    dia = previsao.dia.text
    tempo = previsao.tempo.text
    maxima = previsao.maxima.text
    minima = previsao.minima.text
    iuv = previsao.iuv.text
    
    print("Dia:", dia, " | ", "Tempo:", tempo, " | ","T_max:", maxima, " | ",
          "T_min:", minima, " | ", "IUV:", iuv)
# Out:
# Cidade: São Paulo
# Dia: 2021-04-13  |  Tempo: ci  |  T_max: 21  |  T_min: 17  |  IUV: 8.0
# Dia: 2021-04-14  |  Tempo: pn  |  T_max: 23  |  T_min: 14  |  IUV: 8.0
# Dia: 2021-04-15  |  Tempo: n  |  T_max: 25  |  T_min: 16  |  IUV: 8.0
# Dia: 2021-04-16  |  Tempo: n  |  T_max: 25  |  T_min: 15  |  IUV: 8.0

# %%
import requests
import bs4

codigos_cidades = [244, 241, 222, 797]

for codigo in codigos_cidades:
    
    url = f'http://servicos.cptec.inpe.br/XML/cidade/{codigo}/previsao.xml'

    resposta = requests.get(url)
    
    site = bs4.BeautifulSoup(resposta.text, 'lxml')
    
    cidade = site.nome.text
    print("Cidade:", cidade)
    
    for previsao in site.find_all("previsao"):
        
        dia = previsao.dia.text
        tempo = previsao.tempo.text
        maxima = previsao.maxima.text
        minima = previsao.minima.text
        iuv = previsao.iuv.text
        
        print("Dia:", dia, " | ", "Tempo:", tempo, " | ","T_max:", maxima, " | ",
              "T_min:", minima, " | ", "IUV:", iuv)
        
    print("\n#######################################################\n")
# Out:
# Cidade: São Paulo
# Dia: 2021-04-13  |  Tempo: ci  |  T_max: 21  |  T_min: 17  |  IUV: 8.0
# Dia: 2021-04-14  |  Tempo: pn  |  T_max: 23  |  T_min: 14  |  IUV: 8.0
# Dia: 2021-04-15  |  Tempo: n  |  T_max: 25  |  T_min: 16  |  IUV: 8.0
# Dia: 2021-04-16  |  Tempo: n  |  T_max: 25  |  T_min: 15  |  IUV: 8.0
#
# #######################################################
#
# Cidade: Rio de Janeiro
# Dia: 2021-04-13  |  Tempo: c  |  T_max: 27  |  T_min: 24  |  IUV: 8.0
# Dia: 2021-04-14  |  Tempo: pn  |  T_max: 27  |  T_min: 23  |  IUV: 8.0
# Dia: 2021-04-15  |  Tempo: e  |  T_max: 27  |  T_min: 21  |  IUV: 8.0
# Dia: 2021-04-16  |  Tempo: pn  |  T_max: 28  |  T_min: 21  |  IUV: 8.0
#
# #######################################################
#
# Cidade: Belo Horizonte
# Dia: 2021-04-13  |  Tempo: pn  |  T_max: 30  |  T_min: 18  |  IUV: 9.0
# Dia: 2021-04-14  |  Tempo: pn  |  T_max: 27  |  T_min: 18  |  IUV: 9.0
# Dia: 2021-04-15  |  Tempo: c  |  T_max: 27  |  T_min: 16  |  IUV: 9.0
# Dia: 2021-04-16  |  Tempo: pn  |  T_max: 27  |  T_min: 16  |  IUV: 9.0
#
# #######################################################
#
# Cidade: Barueri
# Dia: 2021-04-13  |  Tempo: ci  |  T_max: 22  |  T_min: 18  |  IUV: 8.0
# Dia: 2021-04-14  |  Tempo: pn  |  T_max: 26  |  T_min: 16  |  IUV: 8.0
# Dia: 2021-04-15  |  Tempo: n  |  T_max: 28  |  T_min: 16  |  IUV: 8.0
# Dia: 2021-04-16  |  Tempo: pn  |  T_max: 29  |  T_min: 15  |  IUV: 8.0
#
# #######################################################

# %%
palavra = 'TESTE'
nova_palavra = "_____"
letter = 'T'

for i in range(len(palavra)):
    letra = palavra[i]
    if letter == letra:
        nova_palavra += letra
    else:
        nova_palavra
print(nova_palavra)
