# %% [markdown]
# # Aula 10 - Pandas
#
# Na aula de hoje, vamos explorar os seguintes tópicos em Python:
#
# - 1) Pandas
#
# _______

# %% [markdown]
# ## 1) Pandas
#
# O pandas é uma das bibliotecas mais usadas em data science.
#
# Seu objetivo é a **leitura, processamento e manipulação de dados** na forma de tabelas chamadas de **"DataFrame"**
#
# Antes de conhecer o Pandas, vamos ler o arquivo csv da lista 7, da forma como aprendemos na aula de arquivos

# %%
import csv

with open("alunos.csv", "r", encoding="utf-8") as f:
    leitor = csv.reader(f)
    planilha = []
    for linha in leitor:
        planilha.append(linha)

planilha
# Out:
# [['RA', 'Nome', 'Frequencia', 'Prova_1', 'Prova_2', 'Prova_3', 'Prova_4'],
#  ['110201', 'Antonio Carlos', '20', '6.5', '8.5', '7', '6'],
#  ['110212', 'Ana Beatriz', '20', '7', '7', '7', '8'],
#  ['110218', 'Carlos Vernes', '17', '7', '7', '7', '7'],
#  ['110307', 'Francisco Cunha', '20', '9', '8.5', '8.5', '10'],
#  ['110275', 'Sandra Rosa', '15', '6.5', '7.5', '7', '7'],
#  ['110281', 'Juliana Arruda', '18', '7.5', '7', '7.5', '8'],
#  ['110301', 'Joao Galo', '20', '5', '6.5', '7', '5'],
#  ['110263', 'José Valente', '20', '10', '10', '10', '10'],
#  ['110271', 'Maria Ferreira', '19', '9.5', '8', '7', '10'],
#  ['110236', 'Adriana Tavares', '20', '8', '8', '8', '8']]

# %% [markdown]
# Como fizemos na aula, uma vez lido o arquivo, é possível processá-lo de diversas maneiras.
#
# Por exemplo, para obter **a coluna numero 1**, isto é, os nomes, fazemos:

# %%
[item[1] for item in planilha]
# Out:
# ['Nome',
#  'Antonio Carlos',
#  'Ana Beatriz',
#  'Carlos Vernes',
#  'Francisco Cunha',
#  'Sandra Rosa',
#  'Juliana Arruda',
#  'Joao Galo',
#  'José Valente',
#  'Maria Ferreira',
#  'Adriana Tavares']

# %% [markdown]
# Agora, vamos usar o Pandas e aprender uma forma muito mais natural de processar dados!

# %%
import pandas as pd

# %%
df = pd.read_csv('alunos.csv')
df
# Out:
#        RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4
# 0  110201   Antonio Carlos          20      6.5      8.5      7.0        6
# 1  110212      Ana Beatriz          20      7.0      7.0      7.0        8
# 2  110218    Carlos Vernes          17      7.0      7.0      7.0        7
# 3  110307  Francisco Cunha          20      9.0      8.5      8.5       10
# 4  110275      Sandra Rosa          15      6.5      7.5      7.0        7
# 5  110281   Juliana Arruda          18      7.5      7.0      7.5        8
# 6  110301        Joao Galo          20      5.0      6.5      7.0        5
# 7  110263     José Valente          20     10.0     10.0     10.0       10
# 8  110271   Maria Ferreira          19      9.5      8.0      7.0       10
# 9  110236  Adriana Tavares          20      8.0      8.0      8.0        8

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Podemos **acessar os valores nas colunas** pelo nome delas:

# %%
df['Nome']
# Out:
# 0     Antonio Carlos
# 1        Ana Beatriz
# 2      Carlos Vernes
# 3    Francisco Cunha
# 4        Sandra Rosa
# 5     Juliana Arruda
# 6          Joao Galo
# 7       José Valente
# 8     Maria Ferreira
# 9    Adriana Tavares
# Name: Nome, dtype: object

# %% [markdown]
# Se quisermos obter uma lista propriamente com os valores na coluna, usamos o método `tolist()`:

# %%
df['Nome'].tolist()
# Out:
# ['Antonio Carlos',
#  'Ana Beatriz',
#  'Carlos Vernes',
#  'Francisco Cunha',
#  'Sandra Rosa',
#  'Juliana Arruda',
#  'Joao Galo',
#  'José Valente',
#  'Maria Ferreira',
#  'Adriana Tavares']

# %% [markdown]
# Dá pra **selecionar apenas algumas colunas** do dataframe (ou seja, criando um sub-dataframe):

# %%
df[['Nome', 'Frequencia']]
# Out:
#               Nome  Frequencia
# 0   Antonio Carlos          20
# 1      Ana Beatriz          20
# 2    Carlos Vernes          17
# 3  Francisco Cunha          20
# 4      Sandra Rosa          15
# 5   Juliana Arruda          18
# 6        Joao Galo          20
# 7     José Valente          20
# 8   Maria Ferreira          19
# 9  Adriana Tavares          20

# %% [markdown]
# Dá para acessar linhas do dataframe usando o `.loc`. Dá para acessar valores específicos também com o `.loc`.

# %%
df
# Out:
#        RA             Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4
# 0  110201   Antonio Carlos          20      6.5      8.5      7.0        6
# 1  110212      Ana Beatriz          20      7.0      7.0      7.0        8
# 2  110218    Carlos Vernes          17      7.0      7.0      7.0        7
# 3  110307  Francisco Cunha          20      9.0      8.5      8.5       10
# 4  110275      Sandra Rosa          15      6.5      7.5      7.0        7
# 5  110281   Juliana Arruda          18      7.5      7.0      7.5        8
# 6  110301        Joao Galo          20      5.0      6.5      7.0        5
# 7  110263     José Valente          20     10.0     10.0     10.0       10
# 8  110271   Maria Ferreira          19      9.5      8.0      7.0       10
# 9  110236  Adriana Tavares          20      8.0      8.0      8.0        8

# %%
df.loc[0]
# Out:
# RA                    110201
# Nome          Antonio Carlos
# Frequencia                20
# Prova_1                  6.5
# Prova_2                  8.5
# Prova_3                  7.0
# Prova_4                    6
# Name: 0, dtype: object

# %%
df.loc[0, 'Nome']
# Out:
# 'Antonio Carlos'

# %% [markdown]
# É possível **alterar valores** da tabela. Para isso, primeiro fazemos o slice dos valores que queremos que sejam alterados e depois atribuimos o valor que queremos

# %%
df['Nome'] = list('abcdefghij')
df
# Out:
#        RA Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4
# 0  110201    a          20      6.5      8.5      7.0        6
# 1  110212    b          20      7.0      7.0      7.0        8
# 2  110218    c          17      7.0      7.0      7.0        7
# 3  110307    d          20      9.0      8.5      8.5       10
# 4  110275    e          15      6.5      7.5      7.0        7
# 5  110281    f          18      7.5      7.0      7.5        8
# 6  110301    g          20      5.0      6.5      7.0        5
# 7  110263    h          20     10.0     10.0     10.0       10
# 8  110271    i          19      9.5      8.0      7.0       10
# 9  110236    j          20      8.0      8.0      8.0        8

# %%
df['Nome'] = 'Anonimo'
df
# Out:
#        RA     Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4
# 0  110201  Anonimo          20      6.5      8.5      7.0        6
# 1  110212  Anonimo          20      7.0      7.0      7.0        8
# 2  110218  Anonimo          17      7.0      7.0      7.0        7
# 3  110307  Anonimo          20      9.0      8.5      8.5       10
# 4  110275  Anonimo          15      6.5      7.5      7.0        7
# 5  110281  Anonimo          18      7.5      7.0      7.5        8
# 6  110301  Anonimo          20      5.0      6.5      7.0        5
# 7  110263  Anonimo          20     10.0     10.0     10.0       10
# 8  110271  Anonimo          19      9.5      8.0      7.0       10
# 9  110236  Anonimo          20      8.0      8.0      8.0        8

# %% [markdown]
# **Criando uma coluna nova**, com todas as linhas preenchidas com o mesmo valor

# %%
df['Pais'] = 'Brasil'
df
# Out:
#        RA     Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4    Pais
# 0  110201  Anonimo          20      6.5      8.5      7.0        6  Brasil
# 1  110212  Anonimo          20      7.0      7.0      7.0        8  Brasil
# 2  110218  Anonimo          17      7.0      7.0      7.0        7  Brasil
# 3  110307  Anonimo          20      9.0      8.5      8.5       10  Brasil
# 4  110275  Anonimo          15      6.5      7.5      7.0        7  Brasil
# 5  110281  Anonimo          18      7.5      7.0      7.5        8  Brasil
# 6  110301  Anonimo          20      5.0      6.5      7.0        5  Brasil
# 7  110263  Anonimo          20     10.0     10.0     10.0       10  Brasil
# 8  110271  Anonimo          19      9.5      8.0      7.0       10  Brasil
# 9  110236  Anonimo          20      8.0      8.0      8.0        8  Brasil

# %%
df.columns
# Out:
# Index(['RA', 'Nome', 'Frequencia', 'Prova_1', 'Prova_2', 'Prova_3', 'Prova_4',
#        'Pais'],
#       dtype='object')

# %%
df[['Pais', 'RA', 'Nome', 'Frequencia', 'Prova_1', 'Prova_2', 'Prova_3', 'Prova_4']]
# Out:
#      Pais      RA     Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4
# 0  Brasil  110201  Anonimo          20      6.5      8.5      7.0        6
# 1  Brasil  110212  Anonimo          20      7.0      7.0      7.0        8
# 2  Brasil  110218  Anonimo          17      7.0      7.0      7.0        7
# 3  Brasil  110307  Anonimo          20      9.0      8.5      8.5       10
# 4  Brasil  110275  Anonimo          15      6.5      7.5      7.0        7
# 5  Brasil  110281  Anonimo          18      7.5      7.0      7.5        8
# 6  Brasil  110301  Anonimo          20      5.0      6.5      7.0        5
# 7  Brasil  110263  Anonimo          20     10.0     10.0     10.0       10
# 8  Brasil  110271  Anonimo          19      9.5      8.0      7.0       10
# 9  Brasil  110236  Anonimo          20      8.0      8.0      8.0        8

# %%
df
# Out:
#        RA     Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4    Pais
# 0  110201  Anonimo          20      6.5      8.5      7.0        6  Brasil
# 1  110212  Anonimo          20      7.0      7.0      7.0        8  Brasil
# 2  110218  Anonimo          17      7.0      7.0      7.0        7  Brasil
# 3  110307  Anonimo          20      9.0      8.5      8.5       10  Brasil
# 4  110275  Anonimo          15      6.5      7.5      7.0        7  Brasil
# 5  110281  Anonimo          18      7.5      7.0      7.5        8  Brasil
# 6  110301  Anonimo          20      5.0      6.5      7.0        5  Brasil
# 7  110263  Anonimo          20     10.0     10.0     10.0       10  Brasil
# 8  110271  Anonimo          19      9.5      8.0      7.0       10  Brasil
# 9  110236  Anonimo          20      8.0      8.0      8.0        8  Brasil

# %% [markdown]
# Também é possível **criar uma linha nova**:

# %%
df.loc[11] = [1245245, "Joãozinho", 100, 10, 4, 6, 7, "China"]
df
# Out:
#            RA       Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 0    110201.0    Anonimo        20.0      6.5      8.5      7.0      6.0
# 1    110212.0    Anonimo        20.0      7.0      7.0      7.0      8.0
# 2    110218.0    Anonimo        17.0      7.0      7.0      7.0      7.0
# 3    110307.0    Anonimo        20.0      9.0      8.5      8.5     10.0
# 4    110275.0    Anonimo        15.0      6.5      7.5      7.0      7.0
# 5    110281.0    Anonimo        18.0      7.5      7.0      7.5      8.0
# 6    110301.0    Anonimo        20.0      5.0      6.5      7.0      5.0
# 7    110263.0    Anonimo        20.0     10.0     10.0     10.0     10.0
# 8    110271.0    Anonimo        19.0      9.5      8.0      7.0     10.0
# 9    110236.0    Anonimo        20.0      8.0      8.0      8.0      8.0
# 10  1245245.0  Joãozinho       100.0     10.0      4.0      6.0      7.0
# 11  1245245.0  Joãozinho       100.0     10.0      4.0      6.0      7.0
#
#       Pais
# 0   Brasil
# 1   Brasil
# 2   Brasil
# 3   Brasil
# 4   Brasil
# 5   Brasil
# 6   Brasil
# 7   Brasil
# 8   Brasil
# 9   Brasil
# 10   China
# 11   China

# %% [markdown]
# ou criar uma linha nova com somente alguns elementos

# %%
df.loc[12, 'Nome'] = 'Beto'
df
# Out:
#            RA       Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 0    110201.0    Anonimo        20.0      6.5      8.5      7.0      6.0
# 1    110212.0    Anonimo        20.0      7.0      7.0      7.0      8.0
# 2    110218.0    Anonimo        17.0      7.0      7.0      7.0      7.0
# 3    110307.0    Anonimo        20.0      9.0      8.5      8.5     10.0
# 4    110275.0    Anonimo        15.0      6.5      7.5      7.0      7.0
# 5    110281.0    Anonimo        18.0      7.5      7.0      7.5      8.0
# 6    110301.0    Anonimo        20.0      5.0      6.5      7.0      5.0
# 7    110263.0    Anonimo        20.0     10.0     10.0     10.0     10.0
# 8    110271.0    Anonimo        19.0      9.5      8.0      7.0     10.0
# 9    110236.0    Anonimo        20.0      8.0      8.0      8.0      8.0
# 10  1245245.0  Joãozinho       100.0     10.0      4.0      6.0      7.0
# 11  1245245.0  Joãozinho       100.0     10.0      4.0      6.0      7.0
# 12        NaN       Beto         NaN      NaN      NaN      NaN      NaN
#
#       Pais
# 0   Brasil
# 1   Brasil
# 2   Brasil
# 3   Brasil
# 4   Brasil
# 5   Brasil
# 6   Brasil
# 7   Brasil
# 8   Brasil
# 9   Brasil
# 10   China
# 11   China
# 12     NaN

# %% [markdown]
# Podemos fazer operações entre os valores das colunas, e criar com isso novas colunas!

# %%
df['Media'] = (df['Prova_1'] + df['Prova_2'] + df['Prova_3'] + df['Prova_4'])/4
df
# Out:
#            RA       Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 0    110201.0    Anonimo        20.0      6.5      8.5      7.0      6.0
# 1    110212.0    Anonimo        20.0      7.0      7.0      7.0      8.0
# 2    110218.0    Anonimo        17.0      7.0      7.0      7.0      7.0
# 3    110307.0    Anonimo        20.0      9.0      8.5      8.5     10.0
# 4    110275.0    Anonimo        15.0      6.5      7.5      7.0      7.0
# 5    110281.0    Anonimo        18.0      7.5      7.0      7.5      8.0
# 6    110301.0    Anonimo        20.0      5.0      6.5      7.0      5.0
# 7    110263.0    Anonimo        20.0     10.0     10.0     10.0     10.0
# 8    110271.0    Anonimo        19.0      9.5      8.0      7.0     10.0
# 9    110236.0    Anonimo        20.0      8.0      8.0      8.0      8.0
# 10  1245245.0  Joãozinho       100.0     10.0      4.0      6.0      7.0
# 11  1245245.0  Joãozinho       100.0     10.0      4.0      6.0      7.0
# 12        NaN       Beto         NaN      NaN      NaN      NaN      NaN
#
#       Pais   Media
# 0   Brasil   7.000
# 1   Brasil   7.250
# 2   Brasil   7.000
# 3   Brasil   9.000
# 4   Brasil   7.000
# 5   Brasil   7.500
# 6   Brasil   5.875
# 7   Brasil  10.000
# 8   Brasil   8.625
# 9   Brasil   8.000
# 10   China   6.750
# 11   China   6.750
# 12     NaN     NaN

# %% [markdown]
# Também há algumas funções prontas:

# %%
df[['Prova_1', 'Prova_2', 'Prova_3', 'Prova_4']].mean(axis=1)
# Out:
# 0      7.000
# 1      7.250
# 2      7.000
# 3      9.000
# 4      7.000
# 5      7.500
# 6      5.875
# 7     10.000
# 8      8.625
# 9      8.000
# 10     6.750
# 11     6.750
# 12       NaN
# dtype: float64

# %%
df['Media2'] = df[['Prova_1', 'Prova_2', 'Prova_3', 'Prova_4']].mean(axis=1)
df
# Out:
#            RA       Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 0    110201.0    Anonimo        20.0      6.5      8.5      7.0      6.0
# 1    110212.0    Anonimo        20.0      7.0      7.0      7.0      8.0
# 2    110218.0    Anonimo        17.0      7.0      7.0      7.0      7.0
# 3    110307.0    Anonimo        20.0      9.0      8.5      8.5     10.0
# 4    110275.0    Anonimo        15.0      6.5      7.5      7.0      7.0
# 5    110281.0    Anonimo        18.0      7.5      7.0      7.5      8.0
# 6    110301.0    Anonimo        20.0      5.0      6.5      7.0      5.0
# 7    110263.0    Anonimo        20.0     10.0     10.0     10.0     10.0
# 8    110271.0    Anonimo        19.0      9.5      8.0      7.0     10.0
# 9    110236.0    Anonimo        20.0      8.0      8.0      8.0      8.0
# 10  1245245.0  Joãozinho       100.0     10.0      4.0      6.0      7.0
# 11  1245245.0  Joãozinho       100.0     10.0      4.0      6.0      7.0
# 12        NaN       Beto         NaN      NaN      NaN      NaN      NaN
#
#       Pais   Media  Media2
# 0   Brasil   7.000   7.000
# 1   Brasil   7.250   7.250
# 2   Brasil   7.000   7.000
# 3   Brasil   9.000   9.000
# 4   Brasil   7.000   7.000
# 5   Brasil   7.500   7.500
# 6   Brasil   5.875   5.875
# 7   Brasil  10.000  10.000
# 8   Brasil   8.625   8.625
# 9   Brasil   8.000   8.000
# 10   China   6.750   6.750
# 11   China   6.750   6.750
# 12     NaN     NaN     NaN

# %% [markdown]
# Naturalmente, o resultado é o mesmo!

# %% [markdown]
# Podemos **fazer filtros** muito facilmente
#
# Basta explicitarmos **condições sobre os valores das colunas**, e utilizar isso como indexador do dataframe!

# %%
df['Media'] >= 7
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7      True
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# Name: Media, dtype: bool

# %%
df[df['Nome'] == 'Anonimo']
# Out:
#          RA     Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4    Pais  \
# 0  110201.0  Anonimo        20.0      6.5      8.5      7.0      6.0  Brasil
# 1  110212.0  Anonimo        20.0      7.0      7.0      7.0      8.0  Brasil
# 2  110218.0  Anonimo        17.0      7.0      7.0      7.0      7.0  Brasil
# 3  110307.0  Anonimo        20.0      9.0      8.5      8.5     10.0  Brasil
# 4  110275.0  Anonimo        15.0      6.5      7.5      7.0      7.0  Brasil
# 5  110281.0  Anonimo        18.0      7.5      7.0      7.5      8.0  Brasil
# 6  110301.0  Anonimo        20.0      5.0      6.5      7.0      5.0  Brasil
# 7  110263.0  Anonimo        20.0     10.0     10.0     10.0     10.0  Brasil
# 8  110271.0  Anonimo        19.0      9.5      8.0      7.0     10.0  Brasil
# 9  110236.0  Anonimo        20.0      8.0      8.0      8.0      8.0  Brasil
#
#     Media  Media2
# 0   7.000   7.000
# 1   7.250   7.250
# 2   7.000   7.000
# 3   9.000   9.000
# 4   7.000   7.000
# 5   7.500   7.500
# 6   5.875   5.875
# 7  10.000  10.000
# 8   8.625   8.625
# 9   8.000   8.000

# %%
df[['Nome', 'Prova_1']]
# Out:
#          Nome  Prova_1
# 0     Anonimo      6.5
# 1     Anonimo      7.0
# 2     Anonimo      7.0
# 3     Anonimo      9.0
# 4     Anonimo      6.5
# 5     Anonimo      7.5
# 6     Anonimo      5.0
# 7     Anonimo     10.0
# 8     Anonimo      9.5
# 9     Anonimo      8.0
# 10  Joãozinho     10.0
# 11  Joãozinho     10.0
# 12       Beto      NaN

# %% [markdown]
# Se quisermos fazer filtros mais complexos (filtros compostos, em mais de uma coluna), podemos fazer **conjunções entre filtros**, utilizando os **operadores lógicos de conjunção**.
#
# Obs.: temos os seguintes operadores lógicos:
#
# - &     - corresponde ao "and"
# - |     - corresponde ao "or"
# - ~     - corresponde ao "not"
#
# _

# %%
df[(df['Prova_1'] >= 7) & (df['Prova_2'] >= 7)]
# Out:
#          RA     Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4    Pais  \
# 1  110212.0  Anonimo        20.0      7.0      7.0      7.0      8.0  Brasil
# 2  110218.0  Anonimo        17.0      7.0      7.0      7.0      7.0  Brasil
# 3  110307.0  Anonimo        20.0      9.0      8.5      8.5     10.0  Brasil
# 5  110281.0  Anonimo        18.0      7.5      7.0      7.5      8.0  Brasil
# 7  110263.0  Anonimo        20.0     10.0     10.0     10.0     10.0  Brasil
# 8  110271.0  Anonimo        19.0      9.5      8.0      7.0     10.0  Brasil
# 9  110236.0  Anonimo        20.0      8.0      8.0      8.0      8.0  Brasil
#
#     Media  Media2
# 1   7.250   7.250
# 2   7.000   7.000
# 3   9.000   9.000
# 5   7.500   7.500
# 7  10.000  10.000
# 8   8.625   8.625
# 9   8.000   8.000

# %%
df['Prova_1'] >= 7
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12    False
# Name: Prova_1, dtype: bool

# %%
df['Prova_2'] >= 7
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7      True
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# Name: Prova_2, dtype: bool

# %% [markdown]
# Ex: pegando as médias dos alunos que tiveram nota igual na prova 1 e na prova 4

# %%
df
# Out:
#            RA       Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 0    110201.0    Anonimo        20.0      6.5      8.5      7.0      6.0
# 1    110212.0    Anonimo        20.0      7.0      7.0      7.0      8.0
# 2    110218.0    Anonimo        17.0      7.0      7.0      7.0      7.0
# 3    110307.0    Anonimo        20.0      9.0      8.5      8.5     10.0
# 4    110275.0    Anonimo        15.0      6.5      7.5      7.0      7.0
# 5    110281.0    Anonimo        18.0      7.5      7.0      7.5      8.0
# 6    110301.0    Anonimo        20.0      5.0      6.5      7.0      5.0
# 7    110263.0    Anonimo        20.0     10.0     10.0     10.0     10.0
# 8    110271.0    Anonimo        19.0      9.5      8.0      7.0     10.0
# 9    110236.0    Anonimo        20.0      8.0      8.0      8.0      8.0
# 10  1245245.0  Joãozinho       100.0     10.0      4.0      6.0      7.0
# 11  1245245.0  Joãozinho       100.0     10.0      4.0      6.0      7.0
# 12        NaN       Beto         NaN      NaN      NaN      NaN      NaN
#
#       Pais   Media  Media2
# 0   Brasil   7.000   7.000
# 1   Brasil   7.250   7.250
# 2   Brasil   7.000   7.000
# 3   Brasil   9.000   9.000
# 4   Brasil   7.000   7.000
# 5   Brasil   7.500   7.500
# 6   Brasil   5.875   5.875
# 7   Brasil  10.000  10.000
# 8   Brasil   8.625   8.625
# 9   Brasil   8.000   8.000
# 10   China   6.750   6.750
# 11   China   6.750   6.750
# 12     NaN     NaN     NaN

# %%
df[df['Prova_1'] == df['Prova_4']]['Media']
# Out:
# 2     7.000
# 6     5.875
# 7    10.000
# 9     8.000
# Name: Media, dtype: float64

# %% [markdown]
# E também é bem fácil salvar um dataframe de volta pra CSV ou pro Excel:

# %%
df
# Out:
#            RA       Nome  Frequencia  Prova_1  Prova_2  Prova_3  Prova_4  \
# 0    110201.0    Anonimo        20.0      6.5      8.5      7.0      6.0
# 1    110212.0    Anonimo        20.0      7.0      7.0      7.0      8.0
# 2    110218.0    Anonimo        17.0      7.0      7.0      7.0      7.0
# 3    110307.0    Anonimo        20.0      9.0      8.5      8.5     10.0
# 4    110275.0    Anonimo        15.0      6.5      7.5      7.0      7.0
# 5    110281.0    Anonimo        18.0      7.5      7.0      7.5      8.0
# 6    110301.0    Anonimo        20.0      5.0      6.5      7.0      5.0
# 7    110263.0    Anonimo        20.0     10.0     10.0     10.0     10.0
# 8    110271.0    Anonimo        19.0      9.5      8.0      7.0     10.0
# 9    110236.0    Anonimo        20.0      8.0      8.0      8.0      8.0
# 10  1245245.0  Joãozinho       100.0     10.0      4.0      6.0      7.0
# 11  1245245.0  Joãozinho       100.0     10.0      4.0      6.0      7.0
# 12        NaN       Beto         NaN      NaN      NaN      NaN      NaN
#
#       Pais   Media  Media2
# 0   Brasil   7.000   7.000
# 1   Brasil   7.250   7.250
# 2   Brasil   7.000   7.000
# 3   Brasil   9.000   9.000
# 4   Brasil   7.000   7.000
# 5   Brasil   7.500   7.500
# 6   Brasil   5.875   5.875
# 7   Brasil  10.000  10.000
# 8   Brasil   8.625   8.625
# 9   Brasil   8.000   8.000
# 10   China   6.750   6.750
# 11   China   6.750   6.750
# 12     NaN     NaN     NaN

# %%
df.to_csv('meu_novo_df.csv')

# %% [markdown]
# Agora que entendemos na prática como usar o Pandas, vamos nos aprofundar um pouco mais em sua estrutura!

# %% [markdown]
# ## Series
# O objeto fundamental do Pandas são as **Series**.
#
# As Series são as **colunas das tabelas**, que funcionam como uma espécie de lista.
#
# A diferença é que a série possui um **índice associado**, permitindo o acesso aos conteúdos dessa estrutura por ele, como um dicionário.
#
#
# Podemos criar uma série **a partir de uma lista**, usando a função do pandas `pd.Series()`:

# %%
# definindo uma série com valores e indices

indices = ["a", "b", "c", "d", "e"]
lista = [10, 20, 30, 40, "aaaaa"]

serie = pd.Series(data = lista, index = indices)

serie
# Out:
# a       10
# b       20
# c       30
# d       40
# e    aaaaa
# dtype: object

# %% [markdown]
# Séries de fato são parecidas com dicionários!
#
# Com isso, podemos transformá-la em dicionários:

# %%
dict(serie)
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40, 'e': 'aaaaa'}

# %% [markdown]
# Assim, também podemos **criar uma série a partir de um dicionário**, e os índices e valores são automaticamente capturados:

# %%
dict2 = {"nome": "André", 
        "idade" : 23}

pd.Series(dict2)
# Out:
# nome     André
# idade       23
# dtype: object

# %% [markdown]
# Agora que entendemos a componente fundamental do Pandas, as Séries, vamos falar um pouco mais sobre o **DataFrame**

# %% [markdown]
# ## DataFrame
# O DataFrame é a estrutura que se assemelha a uma tabela/planilha, como vimos acima.
#
# Ao ler um arquivo, um dataframe é criado automaticamente pelo pandas!
#
# Por debaixo dos panos, o dataframe é representado por um dicionário em que a **chave** é o **nome da coluna** e os **valores** são as **Series** (todas com mesmo índice).

# %% [markdown]
# Assim, podemos **criar um dataframe a partir de um dicionario**, usando a função `pd.DataFrame()`

# %%
cadastro = {"nomes" : ["André", "Mariazinha"],
                "idade" : [22, 25],
                "cidade" : ["Mauá", "Santo André"],
                "filhos": [0, 0],
                "altura" : [1.80, 1.65]}

cadastro
# Out:
# {'nomes': ['André', 'Mariazinha'],
#  'idade': [22, 25],
#  'cidade': ['Mauá', 'Santo André'],
#  'filhos': [0, 0],
#  'altura': [1.8, 1.65]}

# %%
df = pd.DataFrame(cadastro)
df
# Out:
#         nomes  idade       cidade  filhos  altura
# 0       André     22         Mauá       0    1.80
# 1  Mariazinha     25  Santo André       0    1.65

# %% [markdown]
# Mas, como vimos, podemos também ler um dataframe a partir de um arquivo.
#
# O arquivo que leremos é relativo ao Titanic! Você pode saber mais sobre estes dados [clicando aqui!](https://www.kaggle.com/c/titanic)

# %%
df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# Agora que temos uma base mais consolidada, vamos aproveitar para ver agora algumas outras funcionalidades do Pandas!

# %% [markdown]
# É possível utilizar o pandas para fazer uma **tabela dinâmica**:

# %%
df.groupby(["Pclass", "Sex"]).mean()
# Out:
#                PassengerId  Survived        Age     SibSp     Parch  \
# Pclass Sex
# 1      female   469.212766  0.968085  34.611765  0.553191  0.457447
#        male     455.729508  0.368852  41.281386  0.311475  0.278689
# 2      female   443.105263  0.921053  28.722973  0.486842  0.605263
#        male     447.962963  0.157407  30.740707  0.342593  0.222222
# 3      female   399.729167  0.500000  21.750000  0.895833  0.798611
#        male     455.515850  0.135447  26.507589  0.498559  0.224784
#
#                      Fare
# Pclass Sex
# 1      female  106.125798
#        male     67.226127
# 2      female   21.970121
#        male     19.741782
# 3      female   16.118810
#        male     12.661633

# %% [markdown]
# Uma grande funcionalidade do pandas é o método `apply()`, utilizado para aplicar uma **função** (muitas vezes, uma **função lambda**) a uma coluna ou linha de um DataFrame
#
# Uma função lambda nada mais é que uma **forma alternativa de declarar uma função**, de um jeito mais direto

# %%
# funcao dobro
def dobro(num):
    return num * 2

# %%
#funcao lambda dobro
dobro_lambda = lambda num: num*2 
dobro_lambda
# Out:
# <function __main__.<lambda>(num)>

# %%
dobro_lambda(20), dobro(20)
# Out:
# (40, 40)

# %%
[num*2 for num in lista_num]

# %% [markdown]
# Vamos selecionar a coluna de idades...

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# Aplicando uma função lambda **a todos os elementos da coluna**, ou seja, **à todas as linhas da tabela, daquela coluna específica**:

# %% [markdown]
# Tomando cada idade + 2, usando a função lambda definida.
#
# Essa função lambda é equivalente a:
#
# ```python
#
# def funcao(x)
#
#     return x + 2
# ```

# %%
df['Age'].apply(lambda x: x + 2)
# Out:
# 0      24.0
# 1      40.0
# 2      28.0
# 3      37.0
# 4      37.0
#        ...
# 886    29.0
# 887    21.0
# 888     NaN
# 889    28.0
# 890    34.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'] + 2
# Out:
# 0      24.0
# 1      40.0
# 2      28.0
# 3      37.0
# 4      37.0
#        ...
# 886    29.0
# 887    21.0
# 888     NaN
# 889    28.0
# 890    34.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# Um outro exemplo:

# %%
# função: transforma todos os números em string, e concatena "!!!!!!!!!" à string
df['Age'].apply(lambda x: str(x) + "!!!!!!!!!")
# Out:
# 0      22.0!!!!!!!!!
# 1      38.0!!!!!!!!!
# 2      26.0!!!!!!!!!
# 3      35.0!!!!!!!!!
# 4      35.0!!!!!!!!!
#            ...
# 886    27.0!!!!!!!!!
# 887    19.0!!!!!!!!!
# 888     nan!!!!!!!!!
# 889    26.0!!!!!!!!!
# 890    32.0!!!!!!!!!
# Name: Age, Length: 891, dtype: object

# %% [markdown]
# Vamos usar `.apply()` para **extrair o sobrenome** dos nomes dos passageiros

# %% [markdown]
# Pra extrarir o sobrenome, note que este está separada do resto do nome por vírgula.
#
# Para perceber isso, dê uma olhada na coluna de nomes:

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# Portanto, podemos usar a função para strings `split(",")`, com quebra na vírgula, e depois selecionar o primeiro elemento da lista gerada!
#
# Vamos aproveitar e **criar uma nova coluna da base**, com os sobrenomes!

# %%
df['Surname'] = df['Name'].apply(lambda x: x.split(',')[0])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked    Surname
# 0        0         A/5 21171   7.2500   NaN        S     Braund
# 1        0          PC 17599  71.2833   C85        C    Cumings
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3        0            113803  53.1000  C123        S   Futrelle
# 4        0            373450   8.0500   NaN        S      Allen
# ..     ...               ...      ...   ...      ...        ...
# 886      0            211536  13.0000   NaN        S   Montvila
# 887      0            112053  30.0000   B42        S     Graham
# 888      2        W./C. 6607  23.4500   NaN        S   Johnston
# 889      0            111369  30.0000  C148        C       Behr
# 890      0            370376   7.7500   NaN        Q     Dooley
#
# [891 rows x 13 columns]

# %% [markdown]
# ## Digressao
# ### Colchete
# - Indexa
# - Cria lista
# - Compreensao de lista
#
# ### Parentesis
# - Executa funçao
# - define funcao
# - organiza precendencia
# - cria tupla
# - cria geradores (avancado)

# %% [markdown]
# __Cruzamento de bases (join, procv)__
#
# Também é possível fazer **cruzamento de bases** com o pandas.
#
# Pra quem conhece SQL: esses são os joins!
#
# Pra quem conhece Excel: essa é uma forma de fazer o procv!

# %%
import pandas as pd

df1 = pd.read_excel("notas.xlsx", sheet_name="notas1").sort_values('prova1')
df1
# Out:
#    RA    aluno  prova1
# 4   5     luke       7
# 2   3      han       8
# 1   2    maria       9
# 0   1     joão      10
# 3   4     leia      10
# 5   7  obi wan      10

# %%
df2 = pd.read_excel("notas.xlsx", sheet_name="notas2")
df2
# Out:
#    RA   aluno  prova2
# 0   1    joão      10
# 1   2   maria       9
# 2   3     han       8
# 3   4    leia      10
# 4   5    luke       7
# 5   6  anakin      10
# 6   2   Maria       0

# %%
df1.merge(df2, how='outer', on=['RA', 'aluno'])
# Out:
#    RA    aluno  prova1  prova2
# 0   5     luke     7.0     7.0
# 1   3      han     8.0     8.0
# 2   2    maria     9.0     9.0
# 3   1     joão    10.0    10.0
# 4   4     leia    10.0    10.0
# 5   7  obi wan    10.0     NaN
# 6   6   anakin     NaN    10.0
# 7   2    Maria     NaN     0.0

# %% [markdown]
# # Exercicio
#
# 1. Leia os dados do dataset do titanic em um dataframe
# 2. Calcule a média dos valores das passagens para as classes de passageiros
# 3. Crie uma nova coluna `SexId` com o valor 0 se o sexo for masculino e 1 se for feminino
# 4. (Desafio) Crie uma coluna com o valor do pronome de tratamento do passageiro

# %%
# 1
import pandas as pd
df = pd.read_csv('titanic.csv')
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
# 2
df2 = df.groupby('Pclass')['Fare'].mean()
df2
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
# 3
df['SexId'] = df['Sex'].apply(lambda s: 0 if s == 'male' else 1)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  SexId
# 0      0         A/5 21171   7.2500   NaN        S      0
# 1      0          PC 17599  71.2833   C85        C      1
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1
# 3      0            113803  53.1000  C123        S      1
# 4      0            373450   8.0500   NaN        S      0

# %% [markdown]
# # Plotando Graficos

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
#plotando seno y=sen(x)
import numpy as np
x = np.linspace(0, 20, 200)
y = np.sin(x)
plt.plot(x, y)
plt.title('Seno de x')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(axis='x')

# %%
# !pip install --quiet investpy

# %%
investpy.__version__
# Out:
# '1.0.4'

# %%
import investpy

df = investpy.get_stock_historical_data(stock='AAPL',
                                        country='United States',
                                        from_date='01/01/2019',
                                        to_date='01/01/2020')
df.head()
# Out:
#              Open   High    Low  Close     Volume Currency
# Date
# 2019-01-02  38.72  39.71  38.56  39.48  148159008      USD
# 2019-01-03  35.99  36.43  35.50  35.55  365248992      USD
# 2019-01-04  36.13  37.14  35.95  37.06  234428000      USD
# 2019-01-07  37.17  37.21  36.47  36.98  219111008      USD
# 2019-01-08  37.39  37.96  37.13  37.69  164100992      USD

# %%
returns = df['Close'].pct_change()
plt.plot(returns)
plt.title('Retornos AAPL 2020')
# Out:
# Text(0.5, 1.0, 'Retornos AAPL 2020')

# %%
df['Close'].head()
# Out:
# Date
# 2019-01-02    39.48
# 2019-01-03    35.55
# 2019-01-04    37.06
# 2019-01-07    36.98
# 2019-01-08    37.69
# Name: Close, dtype: float64

# %%
plt.plot(df['Close'])

# %%
plt.plot(df['Close'])

# %%
df['Close'].plot()
plt.title('AAPL Close')
# Out:
# Text(0.5, 1.0, 'AAPL Close')

# %%
plt.scatter(df['Close'].index, df['Close'], marker='^')

# %%
plt.figure(figsize=(15,7))
df['Open'].plot()

plt.figure(figsize=(15,7))
df['Close'].plot()
plt.legend()

# %%
seaborn
plotly
